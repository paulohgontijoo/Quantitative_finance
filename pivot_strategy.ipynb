# %% [markdown]
# <ul>
# <li>Fonte: http://www.bmfbovespa.com.br/pt_br/produtos/indices/</li>
# <li>yahoo finance API</li>
# </ul>

# %%
E_Day = 11
E_Month = 10
E_Year = 2021
S_Day = E_Day
S_Month = E_Month - 3
S_Year = E_Year

S_Date = str(str(S_Day) + '/' + str(S_Month) + '/' + str(S_Year))
E_Date = str(str(E_Day) + '/' + str(E_Month) + '/' + str(E_Year))

# %%
all_names=['OIBR3.SA','VVAR3.SA','PETR4.SA','COGN3.SA','MGLU3.SA','BBDC4.SA','ITUB4.SA','IRBR3.SA','CIEL3.SA',
'ITSA4.SA','VALE3.SA','ABEV3.SA','USIM5.SA','PETR3.SA','BBAS3.SA','JBSS3.SA','BRML3.SA','GGBR4.SA','GOAU4.SA',
'CSNA3.SA','EMBR3.SA','B3SA3.SA','AZUL4.SA','MRFG3.SA','CMIG4.SA','NGRD3.SA','GOLL4.SA','MEAL3.SA','HAPV3.SA',
'RAIL3.SA','BRFS3.SA','LAME4.SA','CCRO3.SA','JHSF3.SA','POMO4.SA','EQTL3.SA','LREN3.SA','SUZB3.SA','BEEF3.SA',
'BRDT3.SA','CYRE3.SA','UGPA3.SA','RADL3.SA','NTCO3.SA','ENEV3.SA','MULT3.SA','CVCB3.SA','RENT3.SA','DMMO3.SA',
'WEGE3.SA','KLBN11.SA','BBDC3.SA','ELET3.SA','TOTS3.SA','LWSA3.SA','GFSA3.SA','OIBR4.SA','AERI3.SA','AMAR3.SA',
'CRFB3.SA','MRVE3.SA','BBSE3.SA','PRIO3.SA','STBP3.SA','ECOR3.SA','BTOW3.SA','SBSP3.SA','YDUQ3.SA','QUAL3.SA',
'GNDI3.SA','RCSL4.SA','RAPT4.SA','GMAT3.SA','HYPE3.SA'#,'BPAN4.SA'
           ,'PETZ3.SA','BRKM5.SA','LCAM3.SA','DTEX3.SA','VAMO3.SA',
'LIGT3.SA','SAPR4.SA','HGTX3.SA','ELET6.SA','ENBR3.SA','CPFE3.SA','SANB11.SA','MOVI3.SA','EZTC3.SA','NEOE3.SA',
'POSI3.SA','CSMG3.SA','HBSA3.SA','BRPR3.SA','BRAP4.SA','HBOR3.SA','CEAB3.SA','PTBL3.SA','TAEE11.SA','BRSR6.SA',
'IGTA3.SA','BIDI4.SA','FLRY3.SA','EVEN3.SA','MYPK3.SA','CESP6.SA','CASH3.SA','CSAN3.SA','KLBN4.SA','LAME3.SA',
'LINX3.SA','TASA4.SA','SAPR11.SA','BKBR3.SA','ENJU3.SA','ENAT3.SA','ALPA4.SA','TRIS3.SA','EGIE3.SA','SMLS3.SA',
'TRPL4.SA','ODPV3.SA','ALSO3.SA','TCSA3.SA','RANI3.SA','MILS3.SA','PCAR3.SA','CAML3.SA',
'GRND3.SA','LJQQ3.SA','CRPG5.SA'
           ,'CMIG3.SA','BMGB4.SA','SOMA3.SA'
           ,'SMTO3.SA','ENGI11.SA','DIRR3.SA','VIVA3.SA',
'CPLE6.SA','ETER3.SA','TEND3.SA','SLCE3.SA','GUAR3.SA','MDIA3.SA','LAVV3.SA','LOGN3.SA','SEER3.SA','TUPY3.SA',
'LPSB3.SA','PSSA3.SA','VULC3.SA','WIZS3.SA','SLED4.SA','ABCB4.SA','VLID3.SA','OMGE3.SA','BIDI11.SA',
'ITUB3.SA','SQIA3.SA','BOAS3.SA','ALUP11.SA','TPIS3.SA','ANIM3.SA','PFRM3.SA','TECN3.SA','SHOW3.SA',
'ARZZ3.SA','VIVR3.SA','PGMN3.SA','SEQL3.SA','TGMA3.SA','AALR3.SA','MTRE3.SA','MELK3.SA','PARD3.SA','SIMH3.SA',
'BBRK3.SA','PNVL3.SA','LOGG3.SA','ROMI3.SA','PLPL3.SA'
           ,'MDNE3.SA','LEVE3.SA','LUPA3.SA','KLBN3.SA','CCPR3.SA',
'BIDI3.SA','RRRP3.SA'
           ,'JSLG3.SA','CPLE3.SA','AMBP3.SA','PINE4.SA','SAPR3.SA','DMVF3.SA','POMO3.SA','USIM3.SA',
'JPSA3.SA','FESA4.SA','SHUL4.SA','ITSA3.SA','CARD3.SA','UNIP6.SA','SLED3.SA','AGRO3.SA','PRNR3.SA',
'LLIS3.SA','SGPS3.SA','FHER3.SA','SANB4.SA','PMAM3.SA','TASA3.SA','RSID3.SA','SANB3.SA','FRAS3.SA','TAEE4.SA',
'GGBR3.SA','UCAS3.SA','KEPL3.SA','GPCP3.SA','VIVT3.SA','CAMB3.SA','BOBR4.SA','ATOM3.SA','GOAU3.SA',
'IGBR3.SA','EUCA4.SA','RCSL3.SA','TAEE3.SA','PDGR3.SA','RPMG3.SA','ALPK3.SA','TCNO4.SA','HAGA4.SA','JBDU4.SA',
'AZEV4.SA','EALT4.SA','TESA3.SA','RNEW4.SA','BEES3.SA','WHRL4.SA','APER3.SA','RDNI3.SA','EQPA3.SA','MMXM3.SA',
'BIOM3.SA','BRAP3.SA','ENGI4.SA','TCNO3.SA','PTNT4.SA','ALUP4.SA','CTNM4.SA','COCE5.SA','RNEW3.SA','BRKM3.SA',
'ADHM3.SA','PNVL4.SA','OFSA3.SA','TELB4.SA','ALUP3.SA','RAPT3.SA','SNSY5.SA','CGRA4.SA','CRPG5.SA','SULA4.SA',
'ATMP3.SA','BPAC11.SA','INEP4.SA','ENGI3.SA','BRSR3.SA','MWET4.SA','TXRX4.SA','FRTA3.SA','WHRL3.SA','SCAR3.SA',
'JBDU3.SA','OSXB3.SA','CESP3.SA','HAGA3.SA','CTSA4.SA','INEP3.SA','BMEB4.SA','AZEV3.SA','MNPR3.SA','CTSA3.SA',
'CLSC4.SA','SULA3.SA','UNIP3.SA','DOHL4.SA','EMAE4.SA','TEKA4.SA','HOOT4.SA','MTSA4.SA','BPAC5.SA','BEES4.SA',
'CEDO4.SA']

# %%
# %matplotlib notebook 
# %matplotlib inline 

import matplotlib.dates as mdates
#from matplotlib.finance import candlestick_ohlc
import datetime
from datetime import timedelta
from pandas import *
import matplotlib.mlab as mlab
import scipy.signal as signal
import matplotlib.pyplot as plt
import numpy as np
from numpy import cov
import pandas as pd
import seaborn as sns
import pandas_datareader.data as pdr
import yfinance as yf
import investpy
import datetime as dt
import matplotlib.ticker as mticker
from pandas_datareader import data
import math
import pandas_datareader as web
from mpl_finance import candlestick_ohlc
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression  
from statistics import variance
from statsmodels import *
import statsmodels.api as sm
from pandas.plotting import register_matplotlib_converters
from tqdm import tqdm
register_matplotlib_converters()
sns.set()
# Out:
# /home/gobellek/Documents/Finance/quantenv/lib/python3.7/site-packages/mpl_finance.py:22: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   category=DeprecationWarning)

# %%
ret_free_risk = 0.0525

# %%
def yahoo(symbols,S_Day, S_Month, S_Year, E_Day, E_Month, E_Year):
    yf.pdr_override()       
    stocks_yahoo = pdr.get_data_yahoo(symbols, start=datetime(S_Year, S_Month, S_Day).date(),
                                      end=datetime(E_Year, E_Month, E_Day).date(),
                                      as_panel = False)
    return stocks_yahoo

# %%
# def yahoo(symbols,S_Day, S_Month, S_Year, E_Day, E_Month, E_Year):  
#     S_Date = str(str(S_Day) + '/' + str(S_Month) + '/' + str(S_Year))
#     E_Date = str(str(E_Day) + '/' + str(E_Month) + '/' + str(E_Year))
#     output=None
#     sym=[]
#     for stock in symbols:
#         try:
#             df = investpy.get_stock_historical_data(stock=stock,country='Brazil', 
#                                                     from_date=S_Date, 
#                                                     to_date=E_Date)
#             if output is None:
#                 output=df
#             else:
#                 output=pd.concat([output,df],axis=1)
#             sym.append(stock)
#         except:
#             print("erro",stock)
#     output.columns=sym

#     return stocks_yahoo

# %%
def download(rb):
    stocks_all=yahoo(rb,S_Day, S_Month, S_Year, E_Day, E_Month, E_Year)
    return stocks_all

# %%
def Remove(duplicate): 
    final_list = [] 
    for num in duplicate: 
        if num not in final_list: 
            final_list.append(num) 
    return final_list

# %%
def data_state(output):
    plt.figure(figsize=(40,10))
    sns.heatmap(output.isnull(),  cbar=False, cmap = 'summer')
    print(["Erros",np.sum(output.isnull().sum()),"Ativos",len(output.columns),"Núm. de dias", len(output)])

# %%
def normalize_prices(market_close):
    test = market_close.copy()
    test = test.dropna()
    last = test.iloc[-1]
    for i in range(len(test)):
        test.iloc[i] = test.iloc[i]/last
    return test

# %%
def correlation_filter(market_close, qtd, bool):
    market_corr=market_close.pct_change().iloc[0:].corr() 
    corr_list  = market_corr.values.tolist()
    menores_corr = []
    names = []
    for col in market_close.columns:
        names.append(col)
    corr_all = pd.DataFrame(data = corr_list, index = names, columns = names)

    best_corr = []
    for i in range(0, len(corr_all)):
        correlation_list = corr_all.mean().sort_values(ascending = bool) #True = menores correlacoes
        best_corr.append(correlation_list.index[i])

    best_corr = Remove(best_corr[:qtd])
    return best_corr

# %%
def get_real_returns(market_close):
    returns = pd.DataFrame(index = market_close.iloc[0].index, columns=['returns'])
    for i in market_close.iloc[0].index:
        actual_price = market_close[i].iloc[-1]
        if(math.isnan(actual_price)):
            actual_price = market_close[i].dropna()
            actual_price = actual_price.iloc[-1]
        last_price = market_close[i].iloc[0]
        if(math.isnan(last_price)):
            last_price = market_close[i].dropna()
            last_price = last_price[0]
        ret_real = (actual_price-last_price)/last_price 
        returns.loc[i]['returns'] = ret_real
    return returns

# %%
def find_last_dispersion(y):
    for i in range(1,(len(y))):
        if y[-i] != 0:
            return y[-i]

# %%
def plot_prices(market_close):
    fig = plt.subplots(figsize=(50,15))
    ax1=plt.subplot(1,3,3)
    market_close.plot(ax=ax1)
    ax1.set_title('Preços em Reais',fontsize=45)
    ax1.set_ylabel('Preço [R$]',fontsize=35)
    ax1.set_xlabel('Dias',fontsize=35)
    ax1.legend(loc='upper left',fontsize=15)

# %%
def plot_risk_ret(market_close):
    fig = plt.subplots(figsize=(50,15))
    ax2=plt.subplot(1,3, 3) 
    colors = np.random.rand(5)
    x = market_close.diff().dropna().std().values
    y = get_real_returns(market_close).values
    classes = market_close[market_close.columns].mean().values/market_close[market_close.columns].std().values
    lbl = market_close.iloc[0].index

    #Plota o diagrama de risco e retorno dos ativos

    for i in range(len(x)):
        ax2.scatter(x[i],y[i],  s=10*classes, label = market_close.iloc[0].index[i])
        ax2.annotate(market_close.iloc[0].index[i], (x[i], y[i]))

    ax2.legend(loc='upper right', fontsize=15)
    ax2.set_xlabel("Risco",fontsize=35)
    ax2.set_ylabel('Retornos',fontsize=35)
    ax2.set_title('Diagrama Risco Retorno',fontsize=50) 
    ax2.axhline(y=0, color='r', linestyle='-')

    plt.show()

# %%
def plot_ohlc(df1, stocks_all, df1_price_mean, base_price, base_price_std, target_price, best_names, i):
    fig = plt.subplots(figsize=(20,10))
    plt.style.use('seaborn-whitegrid')
    ax1 = plt.subplot(111)
    ema21 = stocks_all['Adj Close'][best_names[i]].dropna().ewm(span=21, adjust=False).mean().dropna()
    ax1.plot(ema21, color="red")
    ema80 = stocks_all['Adj Close'][best_names[i]].dropna().ewm(span=80, adjust=False).mean().dropna()
    ax1.plot(ema80, color="yellow")
    mma200 = stocks_all['Adj Close'][best_names[i]].dropna().rolling(window=200).mean().dropna()
    ax1.plot(mma200, color="blue")

    candlestick_ohlc(ax1, df1.values, width=0.8, colorup='g', colordown='r',alpha=1)
    ax1.set_xlabel("Dias",fontsize=25)
    ax1.set_ylabel('Preços OHLC [R$]',fontsize=25)
    ax1.set_title('Gráfico candlestick '+best_names[i], fontsize=35) 
    ax1.axhline(y=df1_price_mean, color='b', linestyle='-')
    ax1.axhline(y=base_price, color='g', linestyle='-')
    ax1.axhline(y=base_price_std, color='y', linestyle='-')
    ax1.axhline(y=target_price, color='r', linestyle='-')
    ax1.axhline(y=(1.5*target_price), color='r', linestyle='-')
    plt.xticks(fontsize=20,rotation = 45, ha="right")
    ax1.xaxis_date()

# %%
def return_line_plot(ativ_daily_returns, ativ_return_mean, best_names, i):
    fig = plt.figure(figsize = (20,10))
    ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
    ax1.plot(ativ_daily_returns)
    ax1.set_xlabel("Data", fontsize = 25)
    ax1.set_ylabel("Retorno (Diario)", fontsize = 25)
    ax1.set_title('Gráfico de retorno '+best_names[i],fontsize=35) 
    ax1.axhline(y=ativ_return_mean, color='b', linestyle='-')
    ax1.axhline(y=0, color='r', linestyle='-')
    plt.xticks(fontsize=20,rotation = 45, ha="right")
    plt.show()

# %%
def return_line_plot(ativ_daily_returns, ativ_return_mean, best_names, i):
    fig = plt.figure(figsize = (20,10))
    ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
    ax1.plot(ativ_daily_returns)
    ax1.set_xlabel("Data", fontsize = 25)
    ax1.set_ylabel("Retorno (Diario)", fontsize = 25)
    ax1.set_title('Gráfico de retorno '+best_names[i],fontsize=35) 
    ax1.axhline(y=ativ_return_mean, color='b', linestyle='-')
    ax1.axhline(y=0, color='r', linestyle='-')
    plt.xticks(fontsize=20,rotation = 45, ha="right")
    plt.show()

# %%
def price_linear_regression_plot(x, y, regressor, ativ_price_mean, 
                                 base_price, base_price_std, target_price, 
                                 best_names, i):
    fig = plt.figure(figsize = (20,10))
    plt.scatter(x[:-1],y[:-1])
    plt.plot(x, regressor.predict(x), color = 'red')
    plt.axhline(y=ativ_price_mean, color='b', linestyle='-')
    plt.axhline(y=base_price, color='g', linestyle='-')
    plt.axhline(y=base_price_std, color='y', linestyle='-')
    plt.axhline(y=target_price, color='r', linestyle='-')
    plt.axhline(y=(1.5*target_price), color='r', linestyle='-')
    plt.title('Regressao linear preços '+best_names[i], fontsize=35)
    plt.show()

# %%
def return_linear_regression_plot(x, y, regressor, ativ_return_mean, best_names, i):
    fig = plt.figure(figsize = (20,10))
    plt.scatter(x,y)
    plt.plot(x, regressor.predict(x), color = 'red')
    plt.axhline(y=0, color='r', linestyle='-')
    plt.axhline(y=ativ_return_mean, color='b', linestyle='-')
    plt.title('Regressao linear log de retornos '+best_names[i], fontsize=35)
    plt.show()

# %%
# Sharpe
def sharpe(ret_ativ, ret_free_risk, ativ_volatility):
    s = (ret_ativ - ret_free_risk)/ativ_volatility
    return s

def lenght_equalize(n,m):
    maior = n
    menor = m
    if maior >= menor:
        return menor
    else:
        return maior
    
def perf_port_ibov(port_return, ret_ibov):
    menor = lenght_equalize(port_return, ret_ibov)
    if menor == ret_ibov:
        if port_return > 0:
            if ret_ibov > 0:
                return port_return - ret_ibov
            else:      
                return port_return + abs(ret_ibov)
        if port_return < 0:
            return abs(ret_ibov) - abs(port_return) 
    else:
        return -ret_ibov + port_return

def beta(stock, ibov):
    stock = stock.pct_change().dropna()
    ibov_ret = ibov['Adj Close'].pct_change().dropna()
    n = lenght_equalize(len(stock),len(ibov_ret))
    stock = stock[:n]
    ibov_ret = ibov_ret[:n]
    return cov(stock, ibov_ret)[0][1]/variance(ibov_ret)

def traynor(ret_ativ, ret_free_risk, beta):
    excess_ret = (float(ret_ativ) - ret_free_risk)
    return float(excess_ret/beta)

def alpha(ret_ativ, ret_free_risk, beta, ibov_ret):
    alpha = (ret_ativ - ret_free_risk - beta)*(ibov_ret-ret_free_risk)
    return alpha

def r_squared(ativ_ret, ibov_ret):
    n = lenght_equalize(len(ativ_ret),len(ibov_ret))
    ativ_ret = ativ_ret[:n]
    ibov_ret = ibov_ret[:n]
    correlation_matrix = np.corrcoef(ativ_ret, ibov_ret)
    correlation_xy = correlation_matrix[0,1]
    return correlation_xy**2

# %%
def normalize_data(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

def filter_nomalized_data(data):
    return 

def cluster_number(stocks_all, n):
    if len(stocks_all.columns) < n:
        return len(stocks_all.columns)
    else:
        return n

# %%
def clustering(output, n):
    # %matplotlib inline 
    from sklearn.cluster import KMeans
    import matplotlib.lines as mlines
    import matplotlib.transforms as mtransforms


    # retornos=100*output.pct_change()
    retornos = 100*np.log(output / output.shift(1))
    stocks=retornos.columns

    X=100*np.array([[np.std(retornos[sto]),np.mean(retornos[sto])] for sto in stocks])

    N=cluster_number(stocks_all, n)

    kmeans = KMeans(n_clusters=N, random_state=0).fit(X)
    y_kmeans = kmeans.predict(X)

    fig = plt.subplots(figsize=(20,5))

    ax1=plt.subplot(1,1, 1) 
    ax1.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')
    ax1.set_title('Retornos de '+str(len(stocks))+' Ações do Índice Amplo',fontsize=20)
    ax1.set_xlabel('Risco [%]',fontsize=25)
    ax1.set_ylabel('Retorno [%]',fontsize=25)
    line = mlines.Line2D([0, 1], [0, 1], color='red')
    transform = ax1.transAxes
    line.set_transform(transform)
    ax1.add_line(line)

    centers = kmeans.cluster_centers_
    plt.scatter(centers[:, 0], centers[:, 1], c='black', s=150, alpha=0.2);

    best=[]
    for i in range(N):
        ind=retornos[retornos.columns[np.where(y_kmeans==i)[0]]].mean()/retornos[retornos.columns[np.where(y_kmeans==i)[0]]].std()
                                #Para operar na venda np.min
                                #Para operar na venda np.max
        best.append(ind[ind==np.max(ind)])
    rb=list(pd.DataFrame(best).columns)
    print("Ativos com Melhor Relação em Cada Cluster:")

    for r in rb:
        plt.text(X[stocks==r][0][0],X[stocks==r][0][1],r,fontsize=15)
        
    return rb

# %%
def init_analisys(best_names):
    finals_stocks = pd.DataFrame(index = best_names[:], 
                                 columns = ['Reg_price','Coef_price','Reg_int','Coef_int','Rel_price_ret','Pct_up_day'
                                           ,'Pct_up_month','Sharpe','Base_price','Target_buy','Target_sell','Actual_price'
                                           ,'Ret_real','Stop_loss','Std','Beta','Traynor','Alpha','R-squared'
                                           ,'Dispersion'])
    return finals_stocks

# %%
def analisys(stocks_all, finals_stocks):
    
    index = stocks_all.index
    stocks_close=stocks_all['Adj Close']
    best_names = stocks_close.columns
    
    for i in range(len(best_names)):    

            # Calculando retornos diarios e mensais dos 

        ativ_daily_returns = stocks_all['Adj Close'][best_names[i]].dropna().pct_change().dropna()
        ativ_monthly_returns = stocks_all['Adj Close'][best_names[i]].dropna().resample('M').sum()
        ativ_monthly_returns = ativ_monthly_returns.pct_change()
        daily_values = ativ_daily_returns.copy()
        monthly_values = ativ_monthly_returns.copy()


        pos_days = len(daily_values[daily_values >= 0])
        neg_days = len(daily_values[daily_values < 0])

        pos_months = len(monthly_values[monthly_values >= 0])
        neg_months = len(monthly_values[monthly_values < 0])


        ibov_year_returns = ibov['Adj Close'].dropna().resample('Y').sum()
        ibov_daily_returns = ibov['Adj Close'].pct_change().dropna()
        ibov_year_returns = ibov_year_returns.pct_change().dropna().mean()
        ibov_mean = ibov['Adj Close'].dropna().mean()
        ibov_std = ibov['Adj Close'].dropna().std()
        ibov_year_volatility = (ibov_mean/ibov_std)


        # Ativo
        ativ_year_returns = stocks_all['Adj Close'][best_names[i]].dropna().resample('Y').sum()
        ativ_year_returns = ativ_year_returns.pct_change().dropna().mean()
        ativ_return = stocks_all['Adj Close'][best_names[i]].dropna().diff().mean()
        ativ_std = stocks_all['Adj Close'][best_names[i]].dropna().std()

        # Calculando
        sharp = sharpe(ativ_return,ret_free_risk, ativ_std/100)


                # TERCEIRO PLOT

        log_stocks = stocks_all['Adj Close'][best_names[i]]    # Y
        stocks_index = log_stocks.index                                 #Date

        counter = None
        x = None
        y = None
        dispersion_real = None
        dispersion_predict = None

        y = log_stocks.fillna(0)
        dispersion_real = find_last_dispersion(y)
        counter = np.arange(len(y))
        x = counter[:]

        correlacao = np.corrcoef(x,y)

        x = x.reshape(-1,1)

        regressor = LinearRegression()
        regressor.fit(x,y)
        regressor.coef_
        reg_price = regressor.intercept_
        coef_price = regressor.coef_[0]
        
        dispersion_predict = regressor.predict(x)[-1]
        dispersion = dispersion_real/dispersion_predict
        
        base_price_1 = reg_price * (1 + coef_price)
        target_buy_1 = stocks_all['Adj Close'][best_names[i]].iloc[-7:].mean() * (1-coef_price)
        target_sell_1 = stocks_all['Adj Close'][best_names[i]].iloc[-7:].mean() * (1+coef_price)


                # QUARTO PLOT

        log_stocks =  stocks_all['Adj Close'][best_names[i]].pct_change() # Y
        stocks_index = log_stocks.index

        counter = None
        x = None
        y = None

        y = log_stocks.fillna(0)
        counter = np.arange(len(y))
        x = counter[:]

        correlacao = np.corrcoef(x,y)

        x = x.reshape(-1,1)

        regressor = LinearRegression()
        regressor.fit(x,y)
        regressor.coef_
        reg_int = regressor.intercept_
        coef_int = regressor.coef_[0]
        

        base_price = reg_price * (1 + coef_int)
        target_buy_2 = stocks_all['Adj Close'][best_names[i]].iloc[-21:].median() * (1-coef_int*10)
        target_sell_2 = stocks_all['Adj Close'][best_names[i]].iloc[-21:].median() * (1+coef_int*10)

        target_buy = (target_buy_1 + target_buy_2) / 2
        target_sell = (target_sell_1 + target_sell_2) / 2
        

#         pct_up_day = 100*pos_days/(pos_days+neg_days)
#         pct_up_month = 100*pos_months/(pos_months+neg_months)

        ret_ativ = float(get_real_returns(stocks_all['Adj Close']).loc[best_names[i]])
        ibov_ret = float(get_real_returns(ibov).loc['Adj Close'])
        
        beta_coef = beta(stocks_all['Adj Close'][best_names[i]], ibov)
        alpha_coef = alpha(ret_ativ, ret_free_risk, beta_coef, ibov_ret)
        traynor_coef = traynor(ret_ativ, ret_free_risk, beta_coef)
        r_squared_coef = r_squared(ativ_daily_returns, ibov_daily_returns)
        std_coef = np.log(stocks_close[best_names[i]]/stocks_close[best_names[i]].shift(1)).std()
        
        finals_stocks['Reg_price'][best_names[i]] = reg_price
        finals_stocks['Coef_price'][best_names[i]] = coef_price
        finals_stocks['Reg_int'][best_names[i]] = reg_int
        finals_stocks['Coef_int'][best_names[i]] = coef_int
#         finals_stocks['Pct_up_day'][best_names[i]] = pct_up_day
#         finals_stocks['Pct_up_month'][best_names[i]] = pct_up_month
        finals_stocks['Sharpe'][best_names[i]] = sharp
        finals_stocks['Base_price'][best_names[i]] = base_price
        finals_stocks['Target_buy'][best_names[i]] = target_buy
        finals_stocks['Target_sell'][best_names[i]] = target_sell
        finals_stocks['Rel_price_ret'][best_names[i]] = coef_price/coef_int
        finals_stocks['Dispersion'][best_names[i]] = dispersion
        finals_stocks['Std'][best_names[i]] = std_coef
        finals_stocks['Beta'][best_names[i]] = beta_coef
        finals_stocks['Traynor'][best_names[i]] = traynor_coef
        finals_stocks['Alpha'][best_names[i]] = alpha_coef
        finals_stocks['R-squared'][best_names[i]] = r_squared_coef

        actual_price = stocks_close[best_names[i]].iloc[-1]
        if(math.isnan(actual_price)):
            actual_price = stocks_all['Adj Close'][best_names[i]].dropna()
            actual_price = actual_price.iloc[-1]

        finals_stocks['Actual_price'][best_names[i]] = actual_price
        base_price = (base_price+actual_price) / 2

        last_price = stocks_all['Adj Close'][best_names[i]].iloc[0]
        if(math.isnan(last_price)):
            last_price = stocks_all['Adj Close'][best_names[i]].dropna().iloc[0]
        ret_real = (actual_price-last_price)/last_price 
        finals_stocks['Ret_real'][best_names[i]] = ret_real*100
        stop_loss = None
        stop_loss = ((base_price-actual_price)/actual_price)*100
        finals_stocks['Stop_loss'][best_names[i]] = stop_loss


        print("\n===========>",best_names[i])
        print()
        print("------------------------------------Daily Infos--------------------------------------")
        print("Count:")
        print("              Positive - ",pos_days)
        print("              Negative - ",neg_days)
#         print("              Pct Up   - %.2f" % (pct_up_day))
        print()
        print("-----------------------------------Monthly Infos-------------------------------------")
        print("Count:")
        print("              Positive - ",pos_months)
        print("              Negative - ",neg_months)
#         print("              Pct Up   - %.2f" % (pct_up_month))
        print()
        print()
        print("-----------------------------------Other Infos---------------------------------------")
        print("Count:")
        print("              Sharpe      : %.3f" % sharp)
        print("              Alpha       : %.3f" % alpha_coef)
        print("              Beta        : %.3f" % beta_coef)
        print("              R-squared   : %.3f" % r_squared_coef)
        print("              Traynor     : %.3f" % traynor_coef)
        print("              Std         : %.3f" % std_coef)
        print()
        print("              R. price    : %.5f" % reg_price)
        print("              Coef_price  : %.8f" % coef_price)
        print()
        print("              R. intercept: %.5f" % reg_int)
        print("              Coef        : %.8f" % coef_int)
        print()
        print("              Target_sell : %.2f" % target_sell)
        print("              Actual_price: %.2f" % actual_price)
        print("              Target_buy  : %.2f" % target_buy)
        print()
        print("              Base_price  : %.2f" % base_price)
        print("              Stop_loss   : %.2f" % stop_loss + "%")
        print()
        print("              Dispersion  : %.2f" % dispersion + "%")
        print()
        print("              Stock_return: %.2f" % (ret_real*100) + "%")
        print()
        
    return finals_stocks

# %%
def analisys_plot(stocks_all, finals_stocks):
        
    index = stocks_all.index
    stocks_close=stocks_all['Adj Close']
    best_names = stocks_close.columns
    
    for i in range(len(best_names)):
        
        # Ajustes de dados
        df1 = pd.DataFrame(index=index)
        df1['Open']=stocks_all['Open'][best_names[i]]
        df1['High']=stocks_all['High'][best_names[i]]
        df1['Low']=stocks_all['Low'][best_names[i]]
        df1['Close']=stocks_all['Close'][best_names[i]]
        df1['Volume']=stocks_all['Volume'][best_names[i]]
        df1_price_mean=stocks_all['Close'][best_names[i]].mean()
        

        df1.reset_index(inplace=True)
        df1['Date'] = df1['Date'].map(mdates.date2num)


                #PRIMEIRO PLOT
        print()
        print()
        print()


        # Calculando retornos diarios e mensais dos ativos
        ativ_daily_returns = stocks_all['Adj Close'][best_names[i]].dropna().pct_change().dropna()
        ativ_mean_returns = ativ_daily_returns.mean()
        ativ_monthly_returns = stocks_all['Adj Close'][best_names[i]].dropna().resample('M').sum()
        ativ_monthly_returns = ativ_monthly_returns.pct_change()
        daily_values = ativ_daily_returns.copy()
        monthly_values = ativ_monthly_returns.copy()

        pos_days = len(daily_values[daily_values >= 0])
        neg_days = len(daily_values[daily_values < 0])

        pos_months = len(monthly_values[monthly_values >= 0])
        neg_months = len(monthly_values[monthly_values < 0])

        ibov_year_returns = ibov['Adj Close'].dropna().resample('Y').sum()
        ibov_daily_returns = ibov['Adj Close'].pct_change().dropna()
        ibov_year_returns = ibov_year_returns.pct_change().dropna().mean()
        ibov_mean = ibov['Adj Close'].dropna().mean()
        ibov_std = ibov['Adj Close'].dropna().std()
        ibov_year_volatility = (ibov_mean/ibov_std)

        # Ativo
        ativ_year_returns = stocks_all['Adj Close'][best_names[i]].dropna().resample('Y').sum()
        ativ_year_returns = ativ_year_returns.pct_change().dropna().mean()
        ativ_return = None
        ativ_std = None
        ativ_return_mean = stocks_all['Adj Close'][best_names[i]].pct_change().mean()
        ativ_price_mean = stocks_all['Adj Close'][best_names[i]].mean()
        ativ_std = stocks_all['Adj Close'][best_names[i]].dropna().std()

        # Calculando
        sharp = sharpe(ativ_return_mean,ret_free_risk, (ativ_std/100))

        
                # SEGUNDO PLOT

                # TERCEIRO PLOT
        log_stocks = stocks_all['Adj Close'][best_names[i]]    # Y
        if(log_stocks.iloc[-1] == 0):
            log_stocks = log_stocks.iloc[:-1]
        stocks_index = log_stocks.index                                 #Date

        counter = None
        x = None
        y = None
        dispersion_real = None
        dispersion_predict = None

        y = log_stocks.fillna(0)
        dispersion_real = find_last_dispersion(y)
        counter = np.arange(len(y))
        x = counter[:]

        correlacao = np.corrcoef(x,y)

        x = x.reshape(-1,1)

        regressor = LinearRegression()
        regressor.fit(x,y)
        regressor.coef_
        reg_price = regressor.intercept_
        coef_price = regressor.coef_[0]
        dispersion_predict = regressor.predict(x)[-1]

        target_buy_1 = stocks_all['Adj Close'][best_names[i]].iloc[-7:].mean() * (1-coef_price)
        target_sell_1 = stocks_all['Adj Close'][best_names[i]].iloc[-7:].mean() * (1+coef_price)


                # QUARTO PLOT
        log_stocks_return =  stocks_all['Adj Close'][best_names[i]].pct_change() # Y
        if(log_stocks_return.iloc[-1] == 0):
            log_stocks_return = log_stocks_return.iloc[:-2]
        stocks_index = log_stocks_return.index

        counter_return = None
        x_return = None
        y_return = None

        y_return = log_stocks_return.fillna(0)
        y_mean_return = y_return.mean()
        counter_return = np.arange(len(y_return))
        x_return = counter_return[:]

        correlacao_return = np.corrcoef(x_return,y_return)

        x_return = x_return.reshape(-1,1)

        regressor_return = LinearRegression()
        regressor_return.fit(x_return,y_return)
        regressor_return.coef_
        reg_int_return = regressor_return.intercept_
        coef_int_return = regressor_return.coef_[0]

        base_price = reg_price * (1 + coef_price)
        base_price_std = reg_price * (1 + (ativ_std/10))
        target_buy_2 = stocks_close[best_names[i]].iloc[-21:].mean() * (1-coef_int_return)
        target_sell_2 = stocks_close[best_names[i]].iloc[-21:].mean() * (1+coef_int_return)

        target_buy = (target_buy_1 + target_buy_2) / 2
        target_sell = (target_sell_1 + target_sell_2) / 2

        pct_up_day = 100*pos_days/(pos_days+neg_days)
#         pct_up_month = 100*pos_months/(pos_months+neg_months)
        
        ret_ativ = float(get_real_returns(stocks_all['Adj Close']).loc[best_names[i]])
        ibov_ret = float(get_real_returns(ibov).loc['Adj Close'])

        dispersion = dispersion_real/dispersion_predict
        beta_coef = beta(stocks_all['Adj Close'][best_names[i]], ibov)
        alpha_coef = alpha(ret_ativ, ret_free_risk, beta_coef, ibov_ret)
        traynor_coef = traynor(ret_ativ, ret_free_risk, beta_coef)
        r_squared_coef = r_squared(ativ_daily_returns, ibov_daily_returns)
        std_coef = stocks_close[best_names[i]].pct_change().std()

        finals_stocks['Reg_price'][best_names[i]] = reg_price
        finals_stocks['Coef_price'][best_names[i]] = coef_price
        finals_stocks['Reg_int'][best_names[i]] = reg_int_return
        finals_stocks['Coef_int'][best_names[i]] = coef_int_return
        finals_stocks['Pct_up_day'][best_names[i]] = pct_up_day
#         finals_stocks['Pct_up_month'][best_names[i]] = pct_up_month
        finals_stocks['Sharpe'][best_names[i]] = sharp
        finals_stocks['Target_buy'][best_names[i]] = target_buy
        finals_stocks['Target_sell'][best_names[i]] = target_sell
        finals_stocks['Rel_price_ret'][best_names[i]] = coef_price/coef_int_return
        finals_stocks['Dispersion'][best_names[i]] = dispersion
        finals_stocks['Std'][best_names[i]] = std_coef
        finals_stocks['Beta'][best_names[i]] = beta_coef
        finals_stocks['Traynor'][best_names[i]] = traynor_coef
        finals_stocks['Alpha'][best_names[i]] = alpha_coef
        finals_stocks['R-squared'][best_names[i]] = r_squared_coef

        actual_price = stocks_close[best_names[i]].iloc[-1]
        if(math.isnan(actual_price)):
            actual_price = stocks_all['Adj Close'][best_names[i]].dropna().iloc[-1]

        finals_stocks['Actual_price'][best_names[i]] = actual_price
        base_price = (base_price+actual_price) / 2
        base_price_std = (base_price_std+actual_price) / 2
        target_price = 2*(base_price_std - base_price) + base_price_std

        last_price = stocks_all['Adj Close'][best_names[i]].iloc[0]
        if(math.isnan(last_price)):
            last_price = stocks_all['Adj Close'][best_names[i]].dropna().iloc[0]
        ret_real = (actual_price-last_price)/last_price 
        finals_stocks['Ret_real'][best_names[i]] = ret_real*100
        stop_loss = None
        stop_loss = ((base_price-actual_price)/actual_price)*100
        finals_stocks['Stop_loss'][best_names[i]] = stop_loss

#         Plots
        plot_ohlc(df1, stocks_all, df1_price_mean, 
                  base_price, base_price_std, target_price, 
                  best_names, i)
        return_line_plot(ativ_daily_returns, ativ_return_mean, best_names, i) 
        price_linear_regression_plot(x, y, regressor, ativ_price_mean, 
                                     base_price, base_price_std, target_price,
                                     best_names, i)
        return_linear_regression_plot(x_return, y_return, regressor_return, ativ_return_mean, best_names, i)
        df1 = None
        
        
        print("\n===========>",best_names[i])
        print()
        print("------------------------------------Daily Infos--------------------------------------")
        print("Count:")
        print("              Positive - ",pos_days)
        print("              Negative - ",neg_days)
        print("              Pct Up   - %.2f" % (pct_up_day))
        print()
        print("-----------------------------------Monthly Infos-------------------------------------")
        print("Count:")
        print("              Positive - ",pos_months)
        print("              Negative - ",neg_months)
#         print("              Pct Up   - %.2f" % (pct_up_month))
        print()
        print()
        print("-----------------------------------Other Infos---------------------------------------")
        print("Count:")
        print("              Sharpe      : %.3f" % sharp)
        print("              Alpha       : %.3f" % alpha_coef)
        print("              Beta        : %.3f" % beta_coef)
        print("              R-squared   : %.3f" % r_squared_coef)
        print("              Traynor     : %.3f" % traynor_coef)
        print("              Std         : %.3f" % std_coef)
        print()
        print("              R. price    : %.5f" % reg_price)
        print("              Coef_price  : %.8f" % coef_price)
        print()
        print("              R. intercept: %.5f" % reg_int_return)
        print("              Coef        : %.8f" % coef_int_return)
        print()
        print("              Target_sell : %.2f" % target_sell)
        print("              Actual_price: %.2f" % actual_price)
        print("              Target_buy  : %.2f" % target_buy)
        print()
        print("              Base_price  : %.2f" % base_price)
        print("              Stop_loss   : %.2f" % stop_loss + "%")
        print()
        print("              Dispersion  : %.2f" % dispersion + "%")
        print()
        print("              Stock_return: %.2f" % (ret_real*100) + "%")
        print()
        
    return finals_stocks

# %%
def routine(best_names):
    finals_stocks = init_analisys(stocks_all['Close'][best_names].columns)
    analisys(stocks_all, finals_stocks)
    return finals_stocks

# %%
def routine_plot(best_names):
    stocks_all = None
    stocks_all = download(best_names)
    finals_stocks = init_analisys(stocks_all['Close'][best_names].columns)
    analisys_plot(stocks_all, finals_stocks)
    return finals_stocks, stocks_all

# %%
def best_volumes(all_names, qtd):
    market_all=yahoo(all_names,S_Day, S_Month, S_Year, E_Day, E_Month, E_Year)
    market_close=market_all['Adj Close']
    lista=market_all['Volume'].mean().sort_values(ascending = False)[:qtd].index
    names = []
    for i in range(0, len(lista)):
        names.append(lista[i]) 
    market_all = market_all[market_close.isin(names)]
    return market_all

# %% [markdown]
# <div id="Tópico 1">
#     <div class="alert alert-block alert-info" style="margin-top: 0px">
# </div> </div>

# %%
# def investpy_activate(all_names):
#     stocks = []
#     for each in all_names:
#         first = each.split()
#         first = each.split('.')
#         first = first[0]
#         stocks.append(first)
#     return stocks
# stocks_investpy = investpy_activate(all_names)

# %% [markdown]
# <h2>Analise dos ativos com maior volume negociado</h2>

# %%
# Coletando serie historica e calculando variaveis
    # Ibovespa
ibov = yahoo('^BVSP',S_Day, S_Month, S_Year, E_Day, E_Month, E_Year)
market=yahoo(all_names,S_Day, S_Month, S_Year, E_Day, E_Month, E_Year)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  293 of 293 completed
#
# 6 Failed downloads:
# - LINX3.SA: No data found, symbol may be delisted
# - TESA3.SA: No data found, symbol may be delisted
# - PNVL4.SA: No data found, symbol may be delisted
# - GPCP3.SA: No data found, symbol may be delisted
# - BTOW3.SA: No data found, symbol may be delisted
# - SMLS3.SA: No data found, symbol may be delisted

# %%
market.tail()
# Out:
#            Adj Close                                                   \
#             AALR3.SA   ABCB4.SA ABEV3.SA ADHM3.SA AERI3.SA   AGRO3.SA
# Date
# 2021-10-04     11.69  15.283893    15.04      NaN     7.80  30.840000
# 2021-10-05     11.80  15.352827    15.18      NaN     8.00  30.860001
# 2021-10-06     12.20  15.018000    15.10      NaN     8.10  30.459999
# 2021-10-07     12.54  15.400000    15.08      NaN     8.15  31.150000
# 2021-10-08     12.78  16.010000    15.36      NaN     8.15  32.509998
#
#                                                       ...    Volume           \
#              ALPA4.SA ALPK3.SA   ALSO3.SA  ALUP11.SA  ...  VIVR3.SA VIVT3.SA
# Date                                                  ...
# 2021-10-04  50.160000     6.07  22.320000  23.860001  ...  26492700  2470900
# 2021-10-05  48.689999     5.80  21.740000  23.650000  ...  13728800  2606600
# 2021-10-06  47.779999     5.90  21.700001  23.570000  ...  15676200  1708200
# 2021-10-07  46.830002     5.74  21.670000  23.680000  ...  15294900  2812400
# 2021-10-08  47.290001     6.15  22.910000  24.400000  ...  21957400  3940000
#
#                                                                             \
#            VLID3.SA VULC3.SA  VVAR3.SA WEGE3.SA WHRL3.SA WHRL4.SA WIZS3.SA
# Date
# 2021-10-04   185800  1067200  32981500  9377000     2900     5200  3497600
# 2021-10-05   203000  1297000  27657900  7446600    21200    31500  1939700
# 2021-10-06   525600  2269000  50481900  7941000     8900    23500  2322000
# 2021-10-07   227400   865900  29142200  6626600    16600    10600  2195900
# 2021-10-08   190000   480500  40514900  7309300     4000     5900  2154700
#
#
#            YDUQ3.SA
# Date
# 2021-10-04  1475300
# 2021-10-05  1396200
# 2021-10-06  3083200
# 2021-10-07  5348600
# 2021-10-08  3789100
#
# [5 rows x 1758 columns]

# %%
data_state(market['Volume'])
# Out:
# ['Erros', 566, 'Ativos', 293, 'Núm. de dias', 64]

# %%
lista_vol = list(market['Volume'].mean().sort_values(ascending = False)[:100].index)
market_all = market.copy()
stocks_drop = all_names.copy()
for name in lista_vol:
    stocks_drop.remove(name)
market_close=market_all['Adj Close'].drop(columns=stocks_drop, axis=1)

# %%
market_close.tail()
# Out:
#             ABEV3.SA  AERI3.SA  AMAR3.SA  ANIM3.SA   AZUL4.SA  B3SA3.SA  \
# Date
# 2021-10-04     15.04      7.80      5.39      9.07  36.959999     12.40
# 2021-10-05     15.18      8.00      5.25      8.74  36.250000     12.15
# 2021-10-06     15.10      8.10      5.26      8.48  35.669998     12.22
# 2021-10-07     15.08      8.15      5.18      8.97  35.360001     12.26
# 2021-10-08     15.36      8.15      5.40      9.30  35.860001     12.49
#
#              BBAS3.SA   BBDC3.SA   BBDC4.SA   BBSE3.SA  ...  TPIS3.SA  \
# Date                                                    ...
# 2021-10-04  29.200001  17.559999  20.730000  19.840000  ...      2.52
# 2021-10-05  30.590000  17.969999  21.080000  19.980000  ...      2.52
# 2021-10-06  30.639999  18.040001  21.240000  19.760000  ...      2.50
# 2021-10-07  30.320000  17.660000  20.709999  19.740000  ...      2.46
# 2021-10-08  30.959999  17.930000  20.850000  20.059999  ...      2.57
#
#             UGPA3.SA   USIM5.SA   VALE3.SA  VAMO3.SA  VIVR3.SA  VVAR3.SA  \
# Date
# 2021-10-04     14.71  15.990000  75.489998     14.70      2.45      7.70
# 2021-10-05     14.70  15.930000  74.949997     14.46      2.36      7.85
# 2021-10-06     14.32  15.780000  77.059998     14.90      2.39      8.12
# 2021-10-07     14.11  15.770000  79.360001     15.48      2.34      7.79
# 2021-10-08     14.70  16.549999  79.849998     15.55      2.40      8.06
#
#              WEGE3.SA  WIZS3.SA   YDUQ3.SA
# Date
# 2021-10-04  38.779999     11.60  23.629999
# 2021-10-05  37.529999     11.72  23.410000
# 2021-10-06  37.509998     11.43  23.330000
# 2021-10-07  37.560001     11.50  25.620001
# 2021-10-08  38.650002     12.00  26.799999
#
# [5 rows x 100 columns]

# %%
data_state(market_close)
# Out:
# ['Erros', 0, 'Ativos', 100, 'Núm. de dias', 64]

# %%
best_corr = correlation_filter(market_close, 75, True)

# %% [markdown]
# <div id="Tópico 2">
#     <div class="alert alert-block alert-info" style="margin-top: 0px">
# </div> </div>

# %%
# Analise dos ativos filtrados
stocks_all=yahoo(best_corr,S_Day, S_Month, S_Year, E_Day, E_Month, E_Year)
# Out:
# [*********************100%***********************]  75 of 75 completed

# %%
best_names = stocks_all['Adj Close'].columns
finals_stocks = routine(best_names)
# Out:
# ===========> AERI3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  28
#               Negative -  35
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -11.078
#               Alpha       : 0.086
#               Beta        : 0.256
#               R-squared   : 0.007
#               Traynor     : -0.998
#               Std         : 0.041
#
#               R. price    : 9.38756
#               Coef_price  : -0.02770536
#
#               R. intercept: -0.00980
#               Coef        : 0.00022431
#
#               Target_sell : 7.91
#               Actual_price: 8.15
#               Target_buy  : 8.11
#
#               Base_price  : 8.77
#               Stop_loss   : 7.61%
#
#               Dispersion  : 1.07%
#
#               Stock_return: -20.33%
#
#
# ===========> BBAS3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  30
#               Negative -  33
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -6.161
#               Alpha       : 0.179
#               Beta        : 0.980
#               R-squared   : 0.543
#               Traynor     : -0.087
#               Std         : 0.018
#
#               R. price    : 31.40266
#               Coef_price  : -0.04078127
#
#               R. intercept: -0.00461
#               Coef        : 0.00013438
#
#               Target_sell : 29.11
#               Actual_price: 30.96
#               Target_buy  : 30.29
#
#               Base_price  : 31.18
#               Stop_loss   : 0.72%
#
#               Dispersion  : 1.07%
#
#               Stock_return: -3.31%
#
#
# ===========> BBSE3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  30
#               Negative -  33
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -9.237
#               Alpha       : 0.171
#               Beta        : 0.853
#               R-squared   : 0.468
#               Traynor     : -0.194
#               Std         : 0.017
#
#               R. price    : 21.58088
#               Coef_price  : -0.04137570
#
#               R. intercept: -0.00634
#               Coef        : 0.00014616
#
#               Target_sell : 19.45
#               Actual_price: 20.06
#               Target_buy  : 20.25
#
#               Base_price  : 20.82
#               Stop_loss   : 3.80%
#
#               Dispersion  : 1.06%
#
#               Stock_return: -11.29%
#
#
# ===========> BEEF3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  32
#               Negative -  31
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -3.030
#               Alpha       : 0.082
#               Beta        : 0.618
#               R-squared   : 0.064
#               Traynor     : 0.207
#               Std         : 0.032
#
#               R. price    : 8.61245
#               Coef_price  : 0.01953526
#
#               R. intercept: -0.00626
#               Coef        : 0.00029710
#
#               Target_sell : 10.58
#               Actual_price: 11.05
#               Target_buy  : 10.34
#
#               Base_price  : 9.83
#               Stop_loss   : -11.02%
#
#               Dispersion  : 1.12%
#
#               Stock_return: 18.06%
#
#
# ===========> BIDI11.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  26
#               Negative -  37
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -4.768
#               Alpha       : 0.402
#               Beta        : 1.975
#               R-squared   : 0.352
#               Traynor     : -0.211
#               Std         : 0.045
#
#               R. price    : 82.94242
#               Coef_price  : -0.52582666
#
#               R. intercept: -0.00305
#               Coef        : -0.00009550
#
#               Target_sell : 39.95
#               Actual_price: 50.01
#               Target_buy  : 64.30
#
#               Base_price  : 66.47
#               Stop_loss   : 32.92%
#
#               Dispersion  : 1.00%
#
#               Stock_return: -36.35%
#
#
# ===========> BIDI4.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  27
#               Negative -  36
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -5.654
#               Alpha       : 0.398
#               Beta        : 1.956
#               R-squared   : 0.344
#               Traynor     : -0.208
#               Std         : 0.045
#
#               R. price    : 27.46386
#               Coef_price  : -0.17615304
#
#               R. intercept: -0.00378
#               Coef        : -0.00006609
#
#               Target_sell : 16.04
#               Actual_price: 16.80
#               Target_buy  : 18.79
#
#               Base_price  : 22.13
#               Stop_loss   : 31.73%
#
#               Dispersion  : 1.03%
#
#               Stock_return: -35.53%
#
#
# ===========> BRAP4.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  27
#               Negative -  36
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -4.024
#               Alpha       : 0.218
#               Beta        : 1.044
#               R-squared   : 0.350
#               Traynor     : -0.243
#               Std         : 0.024
#
#               R. price    : 69.71395
#               Coef_price  : -0.33543557
#
#               R. intercept: -0.00447
#               Coef        : 0.00003949
#
#               Target_sell : 43.50
#               Actual_price: 53.32
#               Target_buy  : 60.86
#
#               Base_price  : 61.52
#               Stop_loss   : 15.38%
#
#               Dispersion  : 1.10%
#
#               Stock_return: -20.10%
#
#
# ===========> BRFS3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  27
#               Negative -  36
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -3.917
#               Alpha       : 0.114
#               Beta        : 0.627
#               R-squared   : 0.229
#               Traynor     : -0.083
#               Std         : 0.017
#
#               R. price    : 25.06045
#               Coef_price  : -0.00722664
#
#               R. intercept: -0.00545
#               Coef        : 0.00017793
#
#               Target_sell : 25.64
#               Actual_price: 26.33
#               Target_buy  : 25.79
#
#               Base_price  : 25.70
#               Stop_loss   : -2.40%
#
#               Dispersion  : 1.07%
#
#               Stock_return: 0.08%
# ===========> BRKM5.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  30
#               Negative -  33
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -2.216
#               Alpha       : 0.195
#               Beta        : 1.067
#               R-squared   : 0.210
#               Traynor     : -0.088
#               Std         : 0.031
#
#               R. price    : 59.44216
#               Coef_price  : 0.03196518
#
#               R. intercept: 0.00143
#               Coef        : -0.00005129
#
#               Target_sell : 59.57
#               Actual_price: 57.89
#               Target_buy  : 57.73
#
#               Base_price  : 58.66
#               Stop_loss   : 1.34%
#
#               Dispersion  : 0.94%
#
#               Stock_return: -4.16%
#
#
# ===========> BRPR3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  29
#               Negative -  34
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -18.351
#               Alpha       : 0.149
#               Beta        : 0.705
#               R-squared   : 0.270
#               Traynor     : -0.256
#               Std         : 0.018
#
#               R. price    : 8.98812
#               Coef_price  : -0.01563461
#
#               R. intercept: -0.00321
#               Coef        : 0.00003901
#
#               Target_sell : 8.02
#               Actual_price: 8.03
#               Target_buy  : 8.14
#
#               Base_price  : 8.51
#               Stop_loss   : 5.97%
#
#               Dispersion  : 1.00%
#
#               Stock_return: -12.81%
#
#
# ===========> CASH3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  29
#               Negative -  34
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -4.957
#               Alpha       : 0.469
#               Beta        : 2.353
#               R-squared   : 0.296
#               Traynor     : -0.186
#               Std         : 0.058
#
#               R. price    : 11.39179
#               Coef_price  : -0.09971298
#
#               R. intercept: 0.00261
#               Coef        : -0.00027205
#
#               Target_sell : 5.87
#               Actual_price: 5.67
#               Target_buy  : 6.46
#
#               Base_price  : 8.53
#               Stop_loss   : 50.43%
#
#               Dispersion  : 1.11%
#
#               Stock_return: -38.55%
#
#
# ===========> CCRO3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  29
#               Negative -  34
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -9.231
#               Alpha       : 0.183
#               Beta        : 0.938
#               R-squared   : 0.461
#               Traynor     : -0.157
#               Std         : 0.019
#
#               R. price    : 13.60242
#               Coef_price  : -0.03628709
#
#               R. intercept: -0.00512
#               Coef        : 0.00011834
#
#               Target_sell : 11.59
#               Actual_price: 12.32
#               Target_buy  : 12.01
#
#               Base_price  : 12.96
#               Stop_loss   : 5.21%
#
#               Dispersion  : 1.09%
#
#               Stock_return: -9.48%
#
#
# ===========> CIEL3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  23
#               Negative -  40
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -14.844
#               Alpha       : 0.298
#               Beta        : 1.468
#               R-squared   : 0.372
#               Traynor     : -0.207
#               Std         : 0.032
#
#               R. price    : 3.63453
#               Coef_price  : -0.02314917
#
#               R. intercept: -0.01018
#               Coef        : 0.00019551
#
#               Target_sell : 2.36
#               Actual_price: 2.64
#               Target_buy  : 2.41
#
#               Base_price  : 3.14
#               Stop_loss   : 18.85%
#
#               Dispersion  : 1.21%
#
#               Stock_return: -25.11%
#
#
# ===========> CMIG4.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  35
#               Negative -  28
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -2.168
#               Alpha       : 0.087
#               Beta        : 0.626
#               R-squared   : 0.305
#               Traynor     : 0.178
#               Std         : 0.015
#
#               R. price    : 11.44232
#               Coef_price  : 0.04553159
#
#               R. intercept: 0.00055
#               Coef        : 0.00006141
#
#               Target_sell : 14.34
#               Actual_price: 14.13
#               Target_buy  : 13.69
#
#               Base_price  : 12.79
#               Stop_loss   : -9.51%
#
#               Dispersion  : 0.99%
#
#               Stock_return: 16.39%
#
#
# ===========> CPLE6.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  35
#               Negative -  28
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -8.929
#               Alpha       : 0.105
#               Beta        : 0.765
#               R-squared   : 0.251
#               Traynor     : 0.182
#               Std         : 0.020
#
#               R. price    : 5.51663
#               Coef_price  : 0.02017495
#
#               R. intercept: 0.00344
#               Coef        : -0.00001572
#
#               Target_sell : 6.68
#               Actual_price: 6.65
#               Target_buy  : 6.55
#
#               Base_price  : 6.08
#               Stop_loss   : -8.52%
#
#               Dispersion  : 0.98%
#
#               Stock_return: 19.19%
#
#
# ===========> CRFB3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  24
#               Negative -  39
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -10.597
#               Alpha       : 0.135
#               Beta        : 0.633
#               R-squared   : 0.294
#               Traynor     : -0.272
#               Std         : 0.016
#
#               R. price    : 20.10971
#               Coef_price  : -0.04137958
#
#               R. intercept: -0.00422
#               Coef        : 0.00007465
#
#               Target_sell : 17.64
#               Actual_price: 18.09
#               Target_buy  : 18.36
#
#               Base_price  : 19.10
#               Stop_loss   : 5.59%
#
#               Dispersion  : 1.03%
#
#               Stock_return: -11.97%
#
#
# ===========> CSNA3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  25
#               Negative -  38
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -4.964
#               Alpha       : 0.275
#               Beta        : 1.202
#               R-squared   : 0.336
#               Traynor     : -0.358
#               Std         : 0.028
#
#               R. price    : 48.12909
#               Coef_price  : -0.34015631
#
#               R. intercept: -0.00452
#               Coef        : -0.00007938
#
#               Target_sell : 23.80
#               Actual_price: 28.32
#               Target_buy  : 33.40
#
#               Base_price  : 38.22
#               Stop_loss   : 34.97%
#
#               Dispersion  : 1.06%
#
#               Stock_return: -37.81%
#
#
# ===========> CYRE3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  23
#               Negative -  40
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -8.629
#               Alpha       : 0.299
#               Beta        : 1.487
#               R-squared   : 0.437
#               Traynor     : -0.194
#               Std         : 0.030
#
#               R. price    : 22.22350
#               Coef_price  : -0.07100411
#
#               R. intercept: -0.00645
#               Coef        : 0.00008468
#
#               Target_sell : 17.87
#               Actual_price: 17.91
#               Target_buy  : 19.12
#
#               Base_price  : 20.07
#               Stop_loss   : 12.05%
#
#               Dispersion  : 1.01%
#
#               Stock_return: -23.66%
# ===========> DMMO3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  35
#               Negative -  28
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -96.926
#               Alpha       : 0.216
#               Beta        : 1.034
#               R-squared   : 0.426
#               Traynor     : -0.240
#               Std         : 0.021
#
#               R. price    : 0.93142
#               Coef_price  : -0.00289721
#
#               R. intercept: -0.00175
#               Coef        : -0.00004529
#
#               Target_sell : 0.76
#               Actual_price: 0.74
#               Target_buy  : 0.76
#
#               Base_price  : 0.84
#               Stop_loss   : 12.93%
#
#               Dispersion  : 0.99%
#
#               Stock_return: -19.57%
#
#
# ===========> EMBR3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  30
#               Negative -  33
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : 1.336
#               Alpha       : 0.228
#               Beta        : 1.562
#               R-squared   : 0.351
#               Traynor     : 0.131
#               Std         : 0.035
#
#               R. price    : 17.90860
#               Coef_price  : 0.09381936
#
#               R. intercept: -0.00181
#               Coef        : 0.00018951
#
#               Target_sell : 24.58
#               Actual_price: 24.75
#               Target_buy  : 22.30
#
#               Base_price  : 21.33
#               Stop_loss   : -13.81%
#
#               Dispersion  : 1.04%
#
#               Stock_return: 25.63%
#
#
# ===========> ENBR3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  31
#               Negative -  32
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -9.432
#               Alpha       : 0.106
#               Beta        : 0.613
#               R-squared   : 0.395
#               Traynor     : -0.028
#               Std         : 0.013
#
#               R. price    : 17.52248
#               Coef_price  : 0.01410279
#
#               R. intercept: 0.00032
#               Coef        : 0.00000964
#
#               Target_sell : 18.28
#               Actual_price: 18.32
#               Target_buy  : 18.03
#
#               Base_price  : 17.92
#               Stop_loss   : -2.18%
#
#               Dispersion  : 1.00%
#
#               Stock_return: 3.50%
#
#
# ===========> ENEV3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  30
#               Negative -  33
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -12.827
#               Alpha       : 0.193
#               Beta        : 0.965
#               R-squared   : 0.398
#               Traynor     : -0.187
#               Std         : 0.021
#
#               R. price    : 17.19330
#               Coef_price  : -0.02409295
#
#               R. intercept: -0.00206
#               Coef        : 0.00000421
#
#               Target_sell : 15.83
#               Actual_price: 15.36
#               Target_buy  : 16.21
#
#               Base_price  : 16.28
#               Stop_loss   : 5.97%
#
#               Dispersion  : 0.98%
#
#               Stock_return: -12.78%
#
#
# ===========> EQTL3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  32
#               Negative -  31
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -7.574
#               Alpha       : 0.126
#               Beta        : 0.696
#               R-squared   : 0.347
#               Traynor     : -0.074
#               Std         : 0.016
#
#               R. price    : 24.22057
#               Coef_price  : 0.01995719
#
#               R. intercept: 0.00100
#               Coef        : -0.00002748
#
#               Target_sell : 25.32
#               Actual_price: 24.62
#               Target_buy  : 24.83
#
#               Base_price  : 24.42
#               Stop_loss   : -0.81%
#
#               Dispersion  : 0.97%
#
#               Stock_return: 0.08%
#
#
# ===========> FHER3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  31
#               Negative -  32
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : 2.200
#               Alpha       : 0.150
#               Beta        : 1.501
#               R-squared   : 0.088
#               Traynor     : 0.405
#               Std         : 0.067
#
#               R. price    : 13.06359
#               Coef_price  : 0.25279785
#
#               R. intercept: 0.00686
#               Coef        : 0.00010393
#
#               Target_sell : 30.82
#               Actual_price: 26.90
#               Target_buy  : 23.90
#
#               Base_price  : 19.98
#               Stop_loss   : -25.72%
#
#               Dispersion  : 0.93%
#
#               Stock_return: 66.05%
#
#
# ===========> GGBR4.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  30
#               Negative -  33
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -5.057
#               Alpha       : 0.205
#               Beta        : 1.092
#               R-squared   : 0.416
#               Traynor     : -0.119
#               Std         : 0.023
#
#               R. price    : 30.39181
#               Coef_price  : -0.07271023
#
#               R. intercept: -0.00189
#               Coef        : 0.00002829
#
#               Target_sell : 25.86
#               Actual_price: 27.18
#               Target_buy  : 27.82
#
#               Base_price  : 28.79
#               Stop_loss   : 5.91%
#
#               Dispersion  : 1.05%
#
#               Stock_return: -7.69%
#
#
# ===========> GMAT3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  32
#               Negative -  31
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -12.534
#               Alpha       : 0.109
#               Beta        : 0.662
#               R-squared   : 0.147
#               Traynor     : 0.024
#               Std         : 0.023
#
#               R. price    : 7.50754
#               Coef_price  : -0.00616209
#
#               R. intercept: -0.00390
#               Coef        : 0.00016460
#
#               Target_sell : 7.38
#               Actual_price: 7.97
#               Target_buy  : 7.42
#
#               Base_price  : 7.74
#               Stop_loss   : -2.89%
#
#               Dispersion  : 1.12%
#
#               Stock_return: 6.84%
#
#
# ===========> GNDI3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  27
#               Negative -  36
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -6.521
#               Alpha       : 0.167
#               Beta        : 0.792
#               R-squared   : 0.261
#               Traynor     : -0.252
#               Std         : 0.021
#
#               R. price    : 84.04872
#               Coef_price  : -0.11629375
#
#               R. intercept: 0.00043
#               Coef        : -0.00008577
#
#               Target_sell : 71.59
#               Actual_price: 72.00
#               Target_buy  : 80.04
#
#               Base_price  : 78.02
#               Stop_loss   : 8.36%
#
#               Dispersion  : 0.94%
#
#               Stock_return: -14.71%
#
#
# ===========> GOAU4.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  30
#               Negative -  33
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -8.761
#               Alpha       : 0.188
#               Beta        : 0.984
#               R-squared   : 0.419
#               Traynor     : -0.138
#               Std         : 0.020
#
#               R. price    : 14.00311
#               Coef_price  : -0.03507449
#
#               R. intercept: -0.00259
#               Coef        : 0.00004541
#
#               Target_sell : 12.13
#               Actual_price: 12.51
#               Target_buy  : 12.56
#
#               Base_price  : 13.26
#               Stop_loss   : 5.97%
#
#               Dispersion  : 1.06%
#
#               Stock_return: -8.36%
# ===========> GRND3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  31
#               Negative -  32
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -8.226
#               Alpha       : 0.205
#               Beta        : 1.010
#               R-squared   : 0.275
#               Traynor     : -0.207
#               Std         : 0.026
#
#               R. price    : 11.87429
#               Coef_price  : -0.04146176
#
#               R. intercept: 0.00207
#               Coef        : -0.00013981
#
#               Target_sell : 8.97
#               Actual_price: 9.20
#               Target_buy  : 9.35
#
#               Base_price  : 10.54
#               Stop_loss   : 14.53%
#
#               Dispersion  : 0.99%
#
#               Stock_return: -15.64%
#
#
# ===========> HAPV3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  28
#               Negative -  35
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -12.476
#               Alpha       : 0.164
#               Beta        : 0.766
#               R-squared   : 0.237
#               Traynor     : -0.274
#               Std         : 0.021
#
#               R. price    : 15.13299
#               Coef_price  : -0.01774516
#
#               R. intercept: 0.00099
#               Coef        : -0.00010968
#
#               Target_sell : 13.64
#               Actual_price: 12.87
#               Target_buy  : 13.89
#
#               Base_price  : 14.00
#               Stop_loss   : 8.79%
#
#               Dispersion  : 0.92%
#
#               Stock_return: -15.76%
#
#
# ===========> HBSA3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  26
#               Negative -  37
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -11.219
#               Alpha       : 0.218
#               Beta        : 0.883
#               R-squared   : 0.160
#               Traynor     : -0.470
#               Std         : 0.030
#
#               R. price    : 6.02563
#               Coef_price  : -0.03959821
#
#               R. intercept: -0.01218
#               Coef        : 0.00017776
#
#               Target_sell : 3.87
#               Actual_price: 4.01
#               Target_buy  : 4.02
#
#               Base_price  : 5.02
#               Stop_loss   : 25.15%
#
#               Dispersion  : 1.14%
#
#               Stock_return: -36.25%
#
#
# ===========> HYPE3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  24
#               Negative -  39
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -6.732
#               Alpha       : 0.136
#               Beta        : 0.627
#               R-squared   : 0.184
#               Traynor     : -0.286
#               Std         : 0.020
#
#               R. price    : 36.38930
#               Coef_price  : -0.07319283
#
#               R. intercept: 0.00557
#               Coef        : -0.00023833
#
#               Target_sell : 30.27
#               Actual_price: 29.37
#               Target_buy  : 32.58
#
#               Base_price  : 32.88
#               Stop_loss   : 11.94%
#
#               Dispersion  : 0.92%
#
#               Stock_return: -12.71%
#
#
# ===========> IRBR3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  26
#               Negative -  37
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -17.413
#               Alpha       : 0.204
#               Beta        : 1.069
#               R-squared   : 0.356
#               Traynor     : -0.137
#               Std         : 0.024
#
#               R. price    : 5.84514
#               Coef_price  : -0.01617010
#
#               R. intercept: -0.00201
#               Coef        : 0.00002349
#
#               Target_sell : 4.86
#               Actual_price: 5.11
#               Target_buy  : 4.94
#
#               Base_price  : 5.48
#               Stop_loss   : 7.19%
#
#               Dispersion  : 1.06%
#
#               Stock_return: -9.40%
#
#
# ===========> ITUB4.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  33
#               Negative -  30
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -8.014
#               Alpha       : 0.258
#               Beta        : 1.318
#               R-squared   : 0.384
#               Traynor     : -0.165
#               Std         : 0.030
#
#               R. price    : 30.80957
#               Coef_price  : -0.05067703
#
#               R. intercept: 0.00409
#               Coef        : -0.00020569
#
#               Target_sell : 26.50
#               Actual_price: 24.66
#               Target_buy  : 27.88
#
#               Base_price  : 27.73
#               Stop_loss   : 12.46%
#
#               Dispersion  : 0.89%
#
#               Stock_return: -16.54%
#
#
# ===========> JBSS3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  40
#               Negative -  23
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : 3.625
#               Alpha       : 0.054
#               Beta        : 0.586
#               R-squared   : 0.128
#               Traynor     : 0.456
#               Std         : 0.022
#
#               R. price    : 28.28805
#               Coef_price  : 0.11893925
#
#               R. intercept: 0.00262
#               Coef        : 0.00006215
#
#               Target_sell : 38.32
#               Actual_price: 37.39
#               Target_buy  : 33.89
#
#               Base_price  : 32.84
#               Stop_loss   : -12.17%
#
#               Dispersion  : 1.04%
#
#               Stock_return: 32.00%
#
#
# ===========> KLBN11.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  24
#               Negative -  39
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -10.851
#               Alpha       : 0.135
#               Beta        : 0.577
#               R-squared   : 0.189
#               Traynor     : -0.394
#               Std         : 0.018
#
#               R. price    : 26.27219
#               Coef_price  : -0.04251489
#
#               R. intercept: -0.00187
#               Coef        : -0.00003119
#
#               Target_sell : 22.96
#               Actual_price: 22.40
#               Target_buy  : 23.96
#
#               Base_price  : 24.34
#               Stop_loss   : 8.64%
#
#               Dispersion  : 0.95%
#
#               Stock_return: -17.50%
# ===========> LAME3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  24
#               Negative -  39
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -9.477
#               Alpha       : 0.347
#               Beta        : 1.581
#               R-squared   : 0.313
#               Traynor     : -0.306
#               Std         : 0.038
#
#               R. price    : 7.73091
#               Coef_price  : -0.05683110
#
#               R. intercept: -0.01305
#               Coef        : 0.00015709
#
#               Target_sell : 4.52
#               Actual_price: 4.66
#               Target_buy  : 4.77
#
#               Base_price  : 6.20
#               Stop_loss   : 32.96%
#
#               Dispersion  : 1.12%
#
#               Stock_return: -43.16%
#
#
# ===========> LAME4.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  25
#               Negative -  38
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -9.582
#               Alpha       : 0.383
#               Beta        : 1.804
#               R-squared   : 0.367
#               Traynor     : -0.264
#               Std         : 0.040
#
#               R. price    : 8.06296
#               Coef_price  : -0.05698714
#
#               R. intercept: -0.01354
#               Coef        : 0.00018254
#
#               Target_sell : 4.88
#               Actual_price: 5.00
#               Target_buy  : 5.15
#
#               Base_price  : 6.53
#               Stop_loss   : 30.64%
#
#               Dispersion  : 1.12%
#
#               Stock_return: -42.32%
#
#
# ===========> LCAM3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  30
#               Negative -  33
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -6.626
#               Alpha       : 0.174
#               Beta        : 0.840
#               R-squared   : 0.201
#               Traynor     : -0.233
#               Std         : 0.025
#
#               R. price    : 28.50843
#               Coef_price  : -0.07795626
#
#               R. intercept: -0.00380
#               Coef        : 0.00005375
#
#               Target_sell : 23.60
#               Actual_price: 24.50
#               Target_buy  : 25.45
#
#               Base_price  : 26.50
#               Stop_loss   : 8.18%
#
#               Dispersion  : 1.04%
#
#               Stock_return: -14.32%
#
#
# ===========> LWSA3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  29
#               Negative -  34
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -7.229
#               Alpha       : 0.243
#               Beta        : 1.248
#               R-squared   : 0.322
#               Traynor     : -0.156
#               Std         : 0.029
#
#               R. price    : 26.67790
#               Coef_price  : -0.06962592
#
#               R. intercept: -0.00007
#               Coef        : -0.00006021
#
#               Target_sell : 21.88
#               Actual_price: 22.15
#               Target_buy  : 23.45
#
#               Base_price  : 24.41
#               Stop_loss   : 10.22%
#
#               Dispersion  : 0.99%
#
#               Stock_return: -14.18%
#
#
# ===========> MEAL3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  27
#               Negative -  36
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -21.793
#               Alpha       : 0.267
#               Beta        : 1.323
#               R-squared   : 0.392
#               Traynor     : -0.200
#               Std         : 0.028
#
#               R. price    : 4.08687
#               Coef_price  : -0.01491552
#
#               R. intercept: -0.00621
#               Coef        : 0.00009119
#
#               Target_sell : 3.28
#               Actual_price: 3.30
#               Target_buy  : 3.32
#
#               Base_price  : 3.69
#               Stop_loss   : 11.93%
#
#               Dispersion  : 1.05%
#
#               Stock_return: -21.24%
#
#
# ===========> MGLU3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  27
#               Negative -  36
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -5.747
#               Alpha       : 0.283
#               Beta        : 1.305
#               R-squared   : 0.335
#               Traynor     : -0.287
#               Std         : 0.030
#
#               R. price    : 23.59984
#               Coef_price  : -0.15014377
#
#               R. intercept: -0.00340
#               Coef        : -0.00007055
#
#               Target_sell : 13.86
#               Actual_price: 14.97
#               Target_buy  : 16.01
#
#               Base_price  : 19.28
#               Stop_loss   : 28.82%
#
#               Dispersion  : 1.06%
#
#               Stock_return: -32.26%
#
#
# ===========> MRFG3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  42
#               Negative -  21
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : 3.165
#               Alpha       : 0.027
#               Beta        : 0.593
#               R-squared   : 0.167
#               Traynor     : 0.731
#               Std         : 0.019
#
#               R. price    : 16.35003
#               Coef_price  : 0.12576292
#
#               R. intercept: 0.00025
#               Coef        : 0.00019481
#
#               Target_sell : 25.94
#               Actual_price: 26.15
#               Target_buy  : 22.64
#
#               Base_price  : 21.25
#               Stop_loss   : -18.73%
#
#               Dispersion  : 1.08%
#
#               Stock_return: 48.60%
#
#
# ===========> NTCO3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  25
#               Negative -  38
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -6.291
#               Alpha       : 0.161
#               Beta        : 0.638
#               R-squared   : 0.230
#               Traynor     : -0.497
#               Std         : 0.018
#
#               R. price    : 60.34692
#               Coef_price  : -0.25530907
#
#               R. intercept: -0.00493
#               Coef        : 0.00000939
#
#               Target_sell : 40.09
#               Actual_price: 44.91
#               Target_buy  : 51.50
#
#               Base_price  : 52.63
#               Stop_loss   : 17.19%
#
#               Dispersion  : 1.01%
#
#               Stock_return: -26.44%
#
#
# ===========> OIBR3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  31
#               Negative -  32
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -36.048
#               Alpha       : 0.208
#               Beta        : 0.785
#               R-squared   : 0.101
#               Traynor     : -0.577
#               Std         : 0.033
#
#               R. price    : 1.36650
#               Coef_price  : -0.00780540
#
#               R. intercept: -0.01416
#               Coef        : 0.00021398
#
#               Target_sell : 0.97
#               Actual_price: 0.93
#               Target_buy  : 0.98
#
#               Base_price  : 1.15
#               Stop_loss   : 23.48%
#
#               Dispersion  : 1.06%
#
#               Stock_return: -40.00%
# ===========> PCAR3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  25
#               Negative -  38
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -7.116
#               Alpha       : 0.231
#               Beta        : 0.986
#               R-squared   : 0.236
#               Traynor     : -0.394
#               Std         : 0.027
#
#               R. price    : 35.25037
#               Coef_price  : -0.17945604
#
#               R. intercept: -0.00844
#               Coef        : 0.00007669
#
#               Target_sell : 23.32
#               Actual_price: 24.60
#               Target_buy  : 27.79
#
#               Base_price  : 29.93
#               Stop_loss   : 21.65%
#
#               Dispersion  : 1.03%
#
#               Stock_return: -33.62%
#
#
# ===========> PETR3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  33
#               Negative -  30
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -0.561
#               Alpha       : 0.153
#               Beta        : 0.966
#               R-squared   : 0.333
#               Traynor     : 0.057
#               Std         : 0.022
#
#               R. price    : 26.22875
#               Coef_price  : 0.03144841
#
#               R. intercept: -0.00191
#               Coef        : 0.00011924
#
#               Target_sell : 28.84
#               Actual_price: 29.79
# ...
# Count:
#               Sharpe      : -50.047
#               Alpha       : 0.101
#               Beta        : 0.499
#               R-squared   : 0.215
#               Traynor     : -0.208
#               Std         : 0.014
#
#               R. price    : 4.04145
#               Coef_price  : -0.00380105
#
#               R. intercept: -0.00243
#               Coef        : 0.00005412
#
#               Target_sell : 3.81
#               Actual_price: 3.89
#               Target_buy  : 3.83
#
#               Base_price  : 3.97
#               Stop_loss   : 1.95%
#
#               Dispersion  : 1.02%
#
#               Stock_return: -5.12%
#
#
# ===========> SBSP3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  34
#               Negative -  29
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -2.127
#               Alpha       : 0.129
#               Beta        : 0.753
#               R-squared   : 0.197
#               Traynor     : -0.016
#               Std         : 0.022
#
#               R. price    : 35.12851
#               Coef_price  : 0.02412454
#
#               R. intercept: -0.00232
#               Coef        : 0.00010114
#
#               Target_sell : 37.81
#               Actual_price: 37.87
#               Target_buy  : 36.87
#
#               Base_price  : 36.50
#               Stop_loss   : -3.61%
#
#               Dispersion  : 1.03%
#
#               Stock_return: 4.07%
# ===========> SOMA3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  32
#               Negative -  31
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -4.926
#               Alpha       : 0.227
#               Beta        : 1.290
#               R-squared   : 0.284
#               Traynor     : -0.045
#               Std         : 0.032
#
#               R. price    : 19.06759
#               Coef_price  : -0.03796406
#
#               R. intercept: 0.00667
#               Coef        : -0.00019873
#
#               Target_sell : 16.48
#               Actual_price: 16.63
#               Target_buy  : 17.14
#
#               Base_price  : 17.85
#               Stop_loss   : 7.32%
#
#               Dispersion  : 1.00%
#
#               Stock_return: -0.60%
#
#
# ===========> STBP3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  29
#               Negative -  34
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -11.275
#               Alpha       : 0.275
#               Beta        : 1.372
#               R-squared   : 0.370
#               Traynor     : -0.193
#               Std         : 0.031
#
#               R. price    : 9.36685
#               Coef_price  : -0.03313897
#
#               R. intercept: -0.00526
#               Coef        : 0.00006292
#
#               Target_sell : 7.57
#               Actual_price: 7.53
#               Target_buy  : 7.82
#
#               Base_price  : 8.45
#               Stop_loss   : 12.20%
#
#               Dispersion  : 1.03%
#
#               Stock_return: -21.23%
#
#
# ===========> SUZB3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  26
#               Negative -  37
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -6.732
#               Alpha       : 0.141
#               Beta        : 0.601
#               R-squared   : 0.167
#               Traynor     : -0.394
#               Std         : 0.020
#
#               R. price    : 58.40602
#               Coef_price  : -0.05771108
#
#               R. intercept: 0.00018
#               Coef        : -0.00010048
#
#               Target_sell : 50.93
#               Actual_price: 49.31
#               Target_buy  : 53.93
#
#               Base_price  : 53.86
#               Stop_loss   : 9.22%
#
#               Dispersion  : 0.90%
#
#               Stock_return: -18.43%
#
#
# ===========> TECN3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  35
#               Negative -  28
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -10.148
#               Alpha       : 0.314
#               Beta        : 2.041
#               R-squared   : 0.281
#               Traynor     : 0.085
#               Std         : 0.051
#
#               R. price    : 2.57656
#               Coef_price  : 0.01584341
#
#               R. intercept: -0.00349
#               Coef        : 0.00025152
#
#               Target_sell : 3.47
#               Actual_price: 3.64
#               Target_buy  : 3.41
#
#               Base_price  : 3.11
#               Stop_loss   : -14.60%
#
#               Dispersion  : 1.02%
#
#               Stock_return: 22.56%
#
#
# ===========> TOTS3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  28
#               Negative -  35
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -6.175
#               Alpha       : 0.184
#               Beta        : 0.962
#               R-squared   : 0.329
#               Traynor     : -0.137
#               Std         : 0.022
#
#               R. price    : 37.56113
#               Coef_price  : -0.01220791
#
#               R. intercept: 0.00143
#               Coef        : -0.00007860
#
#               Target_sell : 35.58
#               Actual_price: 34.66
#               Target_buy  : 36.03
#
#               Base_price  : 36.11
#               Stop_loss   : 4.18%
#
#               Dispersion  : 0.94%
#
#               Stock_return: -7.94%
#
#
# ===========> TPIS3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  25
#               Negative -  38
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -23.267
#               Alpha       : 0.387
#               Beta        : 2.025
#               R-squared   : 0.316
#               Traynor     : -0.135
#               Std         : 0.048
#
#               R. price    : 3.07921
#               Coef_price  : -0.00515339
#
#               R. intercept: -0.00386
#               Coef        : 0.00003432
#
#               Target_sell : 2.70
#               Actual_price: 2.57
#               Target_buy  : 2.71
#
#               Base_price  : 2.82
#               Stop_loss   : 9.91%
#
#               Dispersion  : 0.93%
#
#               Stock_return: -22.12%
#
#
# ===========> UGPA3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  24
#               Negative -  39
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -7.376
#               Alpha       : 0.287
#               Beta        : 1.420
#               R-squared   : 0.412
#               Traynor     : -0.200
#               Std         : 0.030
#
#               R. price    : 18.40835
#               Coef_price  : -0.07782063
#
#               R. intercept: -0.00873
#               Coef        : 0.00016040
#
#               Target_sell : 14.10
#               Actual_price: 14.70
#               Target_buy  : 15.22
#
#               Base_price  : 16.56
#               Stop_loss   : 12.62%
#
#               Dispersion  : 1.09%
#
#               Stock_return: -23.19%
#
#
# ===========> USIM5.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  27
#               Negative -  36
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -4.948
#               Alpha       : 0.354
#               Beta        : 1.919
#               R-squared   : 0.494
#               Traynor     : -0.095
#               Std         : 0.036
#
#               R. price    : 19.77978
#               Coef_price  : -0.07672857
#
#               R. intercept: -0.00449
#               Coef        : 0.00009368
#
#               Target_sell : 15.35
#               Actual_price: 16.55
#               Target_buy  : 16.57
#
#               Base_price  : 18.17
#               Stop_loss   : 9.76%
#
#               Dispersion  : 1.11%
#
#               Stock_return: -13.04%
#
#
# ===========> VALE3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  26
#               Negative -  37
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -4.230
#               Alpha       : 0.209
#               Beta        : 0.957
#               R-squared   : 0.386
#               Traynor     : -0.299
#               Std         : 0.021
#
#               R. price    : 107.98169
#               Coef_price  : -0.53895023
#
#               R. intercept: -0.00464
#               Coef        : 0.00002201
#
#               Target_sell : 56.79
#               Actual_price: 79.85
#               Target_buy  : 98.28
#
#               Base_price  : 93.92
#               Stop_loss   : 17.62%
#
#               Dispersion  : 1.08%
#
#               Stock_return: -23.40%
# ===========> VAMO3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  32
#               Negative -  31
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -5.861
#               Alpha       : 0.206
#               Beta        : 1.154
#               R-squared   : 0.264
#               Traynor     : -0.063
#               Std         : 0.030
#
#               R. price    : 17.09485
#               Coef_price  : -0.02844900
#
#               R. intercept: 0.00263
#               Coef        : -0.00007988
#
#               Target_sell : 15.14
#               Actual_price: 15.55
#               Target_buy  : 15.58
#
#               Base_price  : 16.32
#               Stop_loss   : 4.96%
#
#               Dispersion  : 1.02%
#
#               Stock_return: -2.05%
#
#
# ===========> VIVR3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  26
#               Negative -  37
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -15.989
#               Alpha       : 0.357
#               Beta        : 1.685
#               R-squared   : 0.106
#               Traynor     : -0.261
#               Std         : 0.068
#
#               R. price    : 3.69117
#               Coef_price  : -0.02252221
#
#               R. intercept: -0.00736
#               Coef        : 0.00006299
#
#               Target_sell : 2.43
#               Actual_price: 2.40
#               Target_buy  : 2.49
#
#               Base_price  : 3.05
#               Stop_loss   : 26.90%
#
#               Dispersion  : 1.06%
#
#               Stock_return: -38.78%
#
#
# ===========> WEGE3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  29
#               Negative -  34
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -0.047
#               Alpha       : 0.127
#               Beta        : 0.792
#               R-squared   : 0.250
#               Traynor     : 0.049
#               Std         : 0.021
#
#               R. price    : 33.99118
#               Coef_price  : 0.09160082
#
#               R. intercept: 0.00111
#               Coef        : 0.00001521
#
#               Target_sell : 40.86
#               Actual_price: 38.65
#               Target_buy  : 37.32
#
#               Base_price  : 36.32
#               Stop_loss   : -6.03%
#
#               Dispersion  : 0.97%
#
#               Stock_return: 9.17%
#
#
# ===========> WIZS3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  25
#               Negative -  38
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -7.265
#               Alpha       : 0.386
#               Beta        : 1.914
#               R-squared   : 0.351
#               Traynor     : -0.198
#               Std         : 0.043
#
#               R. price    : 17.83792
#               Coef_price  : -0.10051442
#
#               R. intercept: -0.00601
#               Coef        : 0.00002429
#
#               Target_sell : 11.71
#               Actual_price: 12.00
#               Target_buy  : 12.89
#
#               Base_price  : 14.92
#               Stop_loss   : 24.33%
#
#               Dispersion  : 1.04%
#
#               Stock_return: -32.62%
#
#
# ===========> YDUQ3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  24
#               Negative -  39
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -4.615
#               Alpha       : 0.269
#               Beta        : 1.391
#               R-squared   : 0.360
#               Traynor     : -0.150
#               Std         : 0.031
#
#               R. price    : 30.75877
#               Coef_price  : -0.12772894
#
#               R. intercept: -0.01103
#               Coef        : 0.00028096
#
#               Target_sell : 23.14
#               Actual_price: 26.80
#               Target_buy  : 26.20
#
#               Base_price  : 28.78
#               Stop_loss   : 7.40%
#
#               Dispersion  : 1.18%
#
#               Stock_return: -15.56%

# %%
finals_stocks_aux = finals_stocks.copy()
finals_stocks
# Out:
#           Reg_price Coef_price     Reg_int     Coef_int Rel_price_ret  \
# AERI3.SA    9.38756 -0.0277054 -0.00979803  0.000224306      -123.516
# BBAS3.SA    31.4027 -0.0407813 -0.00460558  0.000134376      -303.486
# BBSE3.SA    21.5809 -0.0413757 -0.00633935  0.000146156      -283.092
# BEEF3.SA    8.61245  0.0195353 -0.00625545  0.000297103       65.7525
# BIDI11.SA   82.9424  -0.525827 -0.00305495 -9.54961e-05       5506.26
# ...             ...        ...         ...          ...           ...
# VAMO3.SA    17.0949  -0.028449  0.00263477 -7.98848e-05       356.125
# VIVR3.SA    3.69117 -0.0225222 -0.00735896  6.29904e-05       -357.55
# WEGE3.SA    33.9912  0.0916008  0.00110598  1.52139e-05       6020.86
# WIZS3.SA    17.8379  -0.100514  -0.0060066  2.42918e-05       -4137.8
# YDUQ3.SA    30.7588  -0.127729  -0.0110294  0.000280958      -454.619
#
#           Pct_up_day Pct_up_month     Sharpe Base_price Target_buy  \
# AERI3.SA         NaN          NaN   -11.0776    9.38967    8.11198
# BBAS3.SA         NaN          NaN   -6.16123    31.4069    30.2939
# BBSE3.SA         NaN          NaN   -9.23689     21.584    20.2485
# BEEF3.SA         NaN          NaN   -3.02994    8.61501    10.3427
# BIDI11.SA        NaN          NaN   -4.76784    82.9345    64.3026
# ...              ...          ...        ...        ...        ...
# VAMO3.SA         NaN          NaN   -5.86108    17.0935    15.5787
# VIVR3.SA         NaN          NaN   -15.9888     3.6914    2.48646
# WEGE3.SA         NaN          NaN -0.0470175    33.9917    37.3201
# WIZS3.SA         NaN          NaN   -7.26512    17.8384    12.8863
# YDUQ3.SA         NaN          NaN   -4.61464    30.7674    26.2014
#
#           Target_sell Actual_price Ret_real Stop_loss        Std      Beta  \
# AERI3.SA      7.90802         8.15 -20.3324   7.60533  0.0411914  0.256234
# BBAS3.SA       29.109        30.96 -3.31156  0.721706  0.0177929  0.980088
# BBSE3.SA      19.4515        20.06 -11.2933   3.79868  0.0167291  0.852821
# BEEF3.SA       10.583        11.05  18.0556  -11.0181  0.0322071  0.617755
# BIDI11.SA     39.9517        50.01 -36.3543   32.9179  0.0450076   1.97543
# ...               ...          ...      ...       ...        ...       ...
# VAMO3.SA      15.1384        15.55 -2.04724   4.96299  0.0302517   1.15404
# VIVR3.SA      2.43354          2.4 -38.7755   26.9042  0.0681309   1.68505
# WEGE3.SA      40.8571        38.65  9.16643  -6.02627  0.0209236  0.791838
# WIZS3.SA       11.708           12 -32.6221   24.3265  0.0434601   1.91379
# YDUQ3.SA      23.1415         26.8  -15.564    7.4019   0.030766   1.39131
#
#              Traynor      Alpha   R-squared Dispersion
# AERI3.SA   -0.998399  0.0861215  0.00712108    1.06646
# BBAS3.SA   -0.087355   0.179238    0.543466    1.07375
# BBSE3.SA   -0.193983   0.171257    0.468206    1.05722
# BEEF3.SA    0.207292  0.0823612   0.0643744    1.12261
# BIDI11.SA  -0.210609   0.402215    0.352015    1.00391
# ...              ...        ...         ...        ...
# VAMO3.SA  -0.0632324   0.206367    0.263516    1.01617
# VIVR3.SA   -0.261271    0.35745    0.106496    1.05621
# WEGE3.SA     0.04946    0.12659    0.250193   0.972033
# WIZS3.SA   -0.197891   0.385571     0.35075    1.04298
# YDUQ3.SA     -0.1496   0.269006    0.360047       1.18
#
# [75 rows x 20 columns]

# %% [markdown]
# <h2>Relação entre coeficientes lineares</h2>

# %%
up = len(finals_stocks[finals_stocks["Rel_price_ret"] > 0])
down = len(finals_stocks[finals_stocks["Rel_price_ret"] < 0])
print('Deslocamento do mercado: %.3f' % float(up/down))
# Out:
# Deslocamento do mercado: 0.744

# %%
finals_stocks = finals_stocks[(finals_stocks['Coef_int'] > 0)]
finals_stocks = finals_stocks[(finals_stocks['Dispersion'] > 0.9) & (finals_stocks['Dispersion'] < 1.1)]

# %% [markdown]
# <h2>Retorno dos ativos</h2>

# %%
finals_stocks["Ret_real"].sort_values(ascending=False)
# Out:
# FHER3.SA      66.0494
# MRFG3.SA      48.5959
# JBSS3.SA           32
# EMBR3.SA      25.6345
# TECN3.SA      22.5589
# CMIG4.SA      16.3921
# PETR4.SA      11.2672
# PETR3.SA      10.7869
# WEGE3.SA      9.16643
# SBSP3.SA      4.06705
# ENBR3.SA      3.50282
# BRFS3.SA    0.0760185
# BBAS3.SA     -3.31156
# SAPR4.SA     -5.12195
# GGBR4.SA     -7.68909
# GOAU4.SA     -8.35933
# RAIL3.SA     -9.38897
# IRBR3.SA     -9.39716
# CCRO3.SA     -9.47832
# BBSE3.SA     -11.2933
# CRFB3.SA     -11.9708
# ENEV3.SA     -12.7768
# BRPR3.SA     -12.8122
# LCAM3.SA     -14.3176
# RENT3.SA     -16.5633
# POMO4.SA     -17.7843
# RCSL3.SA     -19.2308
# BRAP4.SA     -20.0997
# AERI3.SA     -20.3324
# STBP3.SA     -21.2343
# MEAL3.SA     -21.2411
# TPIS3.SA     -22.1212
# UGPA3.SA     -23.1882
# VALE3.SA     -23.3992
# CYRE3.SA     -23.6573
# NTCO3.SA     -26.4373
# RCSL4.SA     -27.2727
# QUAL3.SA     -28.1551
# WIZS3.SA     -32.6221
# PCAR3.SA     -33.6212
# PTBL3.SA     -35.5488
# VIVR3.SA     -38.7755
# OIBR3.SA          -40
# Name: Ret_real, dtype: object

# %% [markdown]
# ## Ativos Quantificados em Tendência de Alta

# %%
    # Apenas ativos com preço equilibrado

finals_stocks
select = finals_stocks.copy()
select_2 = select.copy()

list_append = []
for i in range(len(select_2)):
        if  select_2.iloc[i]['Actual_price'] < select_2.iloc[i]['Target_sell']:
            if select_2.iloc[i]['Actual_price'] > select_2.iloc[i]['Target_buy']:
                list_append.append(select_2.index[i])

                
best_names = list_append
balanced_prices = best_names
balanced_prices
# Out:
# ['CMIG4.SA', 'FHER3.SA', 'JBSS3.SA', 'WEGE3.SA']

# %% [markdown]
# ## Pivoteamento de Coeficientes Quantitativos de Performance

# %%
ranking = pd.DataFrame()
ranking['pos'] = range(1,len(finals_stocks)+1)
ranking['R-squared'] = finals_stocks['R-squared'].sort_values(ascending = True).index
ranking['Traynor'] = finals_stocks['Traynor'].sort_values(ascending = False).index
ranking['Alpha'] = finals_stocks['Alpha'].sort_values(ascending = False).index
ranking['Beta'] = finals_stocks['Beta'].sort_values(ascending = True).index
ranking['Sharpe'] = finals_stocks['Sharpe'].sort_values(ascending = False).index
ranking['Coef_int'] = finals_stocks['Coef_int'].sort_values(ascending = False).index
ranking['Reg_int'] = finals_stocks['Reg_int'].sort_values(ascending = False).index
ranking['Ret_real'] = finals_stocks['Ret_real'].sort_values(ascending = False).index
ranking['Std'] = finals_stocks['Std'].sort_values(ascending = True).index
ranking['Corre'] = best_corr[:len(finals_stocks)]

a = ranking.pivot_table(columns='R-squared', values='pos')
b = ranking.pivot_table(columns='Traynor', values='pos')
c = ranking.pivot_table(columns='Alpha', values='pos')
d = ranking.pivot_table(columns='Beta', values='pos')
e = ranking.pivot_table(columns='Sharpe', values='pos')
f = ranking.pivot_table(columns='Coef_int', values='pos')
g = ranking.pivot_table(columns='Reg_int', values='pos')
h = ranking.pivot_table(columns='Ret_real', values='pos')
i = ranking.pivot_table(columns='Std', values='pos')
j = ranking.pivot_table(columns='Corre', values='pos')

t = pd.concat([a,b,c,d,e,f,g,h,i,j], sort=True)
rank = t.dropna(axis=1).sum()
performance_coef_list = list(rank.sort_values(ascending = True).index[:])
best_names = performance_coef_list
performance_coef_list
# Out:
# ['MRFG3.SA',
#  'JBSS3.SA',
#  'FHER3.SA',
#  'BRFS3.SA',
#  'PETR3.SA',
#  'SBSP3.SA',
#  'PETR4.SA',
#  'EMBR3.SA',
#  'WEGE3.SA',
#  'TECN3.SA',
#  'RCSL3.SA',
#  'RENT3.SA',
#  'SAPR4.SA',
#  'LCAM3.SA',
#  'AERI3.SA',
#  'GGBR4.SA',
#  'BRAP4.SA',
#  'GOAU4.SA',
#  'QUAL3.SA',
#  'VALE3.SA',
#  'OIBR3.SA',
#  'NTCO3.SA',
#  'PCAR3.SA',
#  'VIVR3.SA',
#  'RCSL4.SA',
#  'PTBL3.SA']

# %%
set_1 = set(balanced_prices)
set_2 = set(performance_coef_list)

set_names = list(set_1 & set_2)
best_names = set_names
set_names
# Out:
# ['WEGE3.SA', 'FHER3.SA', 'JBSS3.SA']

# %%
if len(set_names) < 5:
    best_names = Remove(balanced_prices + performance_coef_list + set_names)
    if len(best_names) < 5:
        best_names = finals_stocks_aux[(finals_stocks_aux['Coef_int'] > 0) &
                                       (finals_stocks_aux['Dispersion'] > 0.85) & 
                                       (finals_stocks_aux['Dispersion'] < 1.15)].index

# %%
best_names
# Out:
# ['CMIG4.SA',
#  'FHER3.SA',
#  'JBSS3.SA',
#  'WEGE3.SA',
#  'MRFG3.SA',
#  'BRFS3.SA',
#  'PETR3.SA',
#  'SBSP3.SA',
#  'PETR4.SA',
#  'EMBR3.SA',
#  'TECN3.SA',
#  'RCSL3.SA',
#  'RENT3.SA',
#  'SAPR4.SA',
#  'LCAM3.SA',
#  'AERI3.SA',
#  'GGBR4.SA',
#  'BRAP4.SA',
#  'GOAU4.SA',
#  'QUAL3.SA',
#  'VALE3.SA',
#  'OIBR3.SA',
#  'NTCO3.SA',
#  'PCAR3.SA',
#  'VIVR3.SA',
#  'RCSL4.SA',
#  'PTBL3.SA']

# %%
############################################################################################################

# %%
stocks_all = stocks_all['Adj Close'].filter(list(best_names))
stocks_all.tail()
# Out:
#             CMIG4.SA   FHER3.SA   JBSS3.SA   WEGE3.SA   MRFG3.SA   BRFS3.SA  \
# Date
# 2021-10-04     14.08  27.299999  36.740002  38.779999  25.850000  26.870001
# 2021-10-05     14.08  25.129999  37.570000  37.529999  26.230000  27.120001
# 2021-10-06     13.80  26.860001  37.740002  37.509998  26.040001  26.780001
# 2021-10-07     13.74  27.100000  36.700001  37.560001  25.709999  26.379999
# 2021-10-08     14.13  26.900000  37.389999  38.650002  26.150000  26.330000
#
#              PETR3.SA   SBSP3.SA   PETR4.SA   EMBR3.SA  ...   BRAP4.SA  \
# Date                                                    ...
# 2021-10-04  29.379999  37.380001  28.790001  24.049999  ...  51.060001
# 2021-10-05  29.870001  36.840000  29.420000  22.959999  ...  50.189999
# 2021-10-06  29.139999  36.700001  28.639999  23.379999  ...  51.029999
# 2021-10-07  29.200001  37.340000  28.600000  24.090000  ...  52.549999
# 2021-10-08  29.790001  37.869999  29.120001  24.750000  ...  53.320000
#
#             GOAU4.SA   QUAL3.SA   VALE3.SA  OIBR3.SA   NTCO3.SA   PCAR3.SA  \
# Date
# 2021-10-04     12.54  19.139999  75.489998      0.98  45.000000  23.690001
# 2021-10-05     12.52  18.719999  74.949997      0.98  43.349998  25.299999
# 2021-10-06     12.23  18.330000  77.059998      0.94  44.189999  25.520000
# 2021-10-07     12.38  18.379999  79.360001      0.93  44.110001  25.000000
# 2021-10-08     12.51  19.209999  79.849998      0.93  44.910000  24.600000
#
#             VIVR3.SA  RCSL4.SA  PTBL3.SA
# Date
# 2021-10-04      2.45      1.45     10.99
# 2021-10-05      2.36      1.42     10.80
# 2021-10-06      2.39      1.44     10.76
# 2021-10-07      2.34      1.42     10.60
# 2021-10-08      2.40      1.44     11.56
#
# [5 rows x 27 columns]

# %%
data_state(stocks_all)
# Out:
# ['Erros', 0, 'Ativos', 27, 'Núm. de dias', 64]

# %%
normalize_data(stocks_all.isna().sum())
# Out:
# CMIG4.SA   NaN
# FHER3.SA   NaN
# JBSS3.SA   NaN
# WEGE3.SA   NaN
# MRFG3.SA   NaN
# BRFS3.SA   NaN
# PETR3.SA   NaN
# SBSP3.SA   NaN
# PETR4.SA   NaN
# EMBR3.SA   NaN
# TECN3.SA   NaN
# RCSL3.SA   NaN
# RENT3.SA   NaN
# SAPR4.SA   NaN
# LCAM3.SA   NaN
# AERI3.SA   NaN
# GGBR4.SA   NaN
# BRAP4.SA   NaN
# GOAU4.SA   NaN
# QUAL3.SA   NaN
# VALE3.SA   NaN
# OIBR3.SA   NaN
# NTCO3.SA   NaN
# PCAR3.SA   NaN
# VIVR3.SA   NaN
# RCSL4.SA   NaN
# PTBL3.SA   NaN
# dtype: float64

# %%
if not (normalize_data(stocks_all.isna().sum()).isna().any()):
    data = normalize_data(stocks_all.isna().sum())
    data = data[data < 0.90]
    stocks_all = stocks_all.filter(data.index)
    data_state(stocks_all)

# %%
stocks_all.dropna(inplace=True)
data_state(stocks_all)
# Out:
# ['Erros', 0, 'Ativos', 27, 'Núm. de dias', 64]

# %%
size = 3
rb = clustering(stocks_all, size)
# Out:
# Ativos com Melhor Relação em Cada Cluster:

# %%
for each in set_names: rb.append(each)
markowitz_names = Remove(rb)
markowitz_names
# Out:
# ['MRFG3.SA', 'FHER3.SA', 'EMBR3.SA', 'WEGE3.SA', 'JBSS3.SA']

# %%
markowitz_names.append('^GSPC')
# markowitz_names.remove('^GSPC')

# %%
###############################################################################################################

# %%
# Analise dos ativos filtrados
stocks_all=yahoo(markowitz_names,S_Day, S_Month, S_Year, E_Day, E_Month, E_Year)
index = stocks_all.index
stocks_close = stocks_all['Adj Close']
stocks_all.tail()
# Out:
# [*********************100%***********************]  6 of 6 completed
#             Adj Close                                              \
#              EMBR3.SA   FHER3.SA   JBSS3.SA   MRFG3.SA   WEGE3.SA
# Date
# 2021-10-04  24.049999  27.299999  36.740002  25.850000  38.779999
# 2021-10-05  22.959999  25.129999  37.570000  26.230000  37.529999
# 2021-10-06  23.379999  26.860001  37.740002  26.040001  37.509998
# 2021-10-07  24.090000  27.100000  36.700001  25.709999  37.560001
# 2021-10-08  24.750000  26.900000  37.389999  26.150000  38.650002
#
#                              Close                                   ...  \
#                   ^GSPC   EMBR3.SA   FHER3.SA   JBSS3.SA   MRFG3.SA  ...
# Date                                                                 ...
# 2021-10-04  4300.459961  24.049999  27.299999  36.740002  25.850000  ...
# 2021-10-05  4345.720215  22.959999  25.129999  37.570000  26.230000  ...
# 2021-10-06  4363.549805  23.379999  26.860001  37.740002  26.040001  ...
# 2021-10-07  4399.759766  24.090000  27.100000  36.700001  25.709999  ...
# 2021-10-08  4391.339844  24.750000  26.900000  37.389999  26.150000  ...
#
#                  Open                                       Volume             \
#              JBSS3.SA MRFG3.SA   WEGE3.SA        ^GSPC    EMBR3.SA   FHER3.SA
# Date
# 2021-10-04  35.830002    25.52  39.889999  4348.839844  14866000.0  2703500.0
# 2021-10-05  37.009998    25.90  38.900002  4309.870117   8225300.0  2684600.0
# 2021-10-06  37.119999    25.98  37.000000  4319.569824  16418600.0  3408400.0
# 2021-10-07  37.820000    26.18  37.919998  4383.729980   9481000.0  1872300.0
# 2021-10-08  36.980000    25.84  38.049999  4406.509766   9944800.0  1786500.0
#
#
#               JBSS3.SA    MRFG3.SA   WEGE3.SA         ^GSPC
# Date
# 2021-10-04  14834800.0   5229800.0  9377000.0  3.110560e+09
# 2021-10-05  10640500.0   8161800.0  7446600.0  2.967400e+09
# 2021-10-06  13693800.0  10596900.0  7941000.0  3.219590e+09
# 2021-10-07  11347100.0   7338300.0  6626600.0  3.096080e+09
# 2021-10-08   8113400.0   5101500.0  7309300.0  2.401890e+09
#
# [5 rows x 36 columns]

# %%
data_state(stocks_close)
# Out:
# ['Erros', 6, 'Ativos', 6, 'Núm. de dias', 65]

# %%
# stocks_all.dropna(inplace=True)

# %%
# Analise dos ativos filtrados
finals_stocks, stocks_all = routine_plot(markowitz_names)
index = stocks_all.index
stocks_close = stocks_all['Adj Close']
# Out:
# [*********************100%***********************]  6 of 6 completed
# ===========> EMBR3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  30
#               Negative -  33
#               Pct Up   - 47.62
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -2.335
#               Alpha       : 0.080
#               Beta        : 0.682
#               R-squared   : 0.351
#               Traynor     : 0.299
#               Std         : 0.035
#
#               R. price    : 17.88776
#               Coef_price  : 0.08297377
#
#               R. intercept: -0.00172
#               Coef        : 0.00018175
#
#               Target_sell : 24.19
#               Actual_price: 24.75
#               Target_buy  : 22.21
#
#               Base_price  : 22.06
#               Stop_loss   : -10.86%
#
#               Dispersion  : 1.07%
#
#               Stock_return: 25.63%
# ===========> FHER3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  31
#               Negative -  32
#               Pct Up   - 49.21
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -0.794
#               Alpha       : 0.041
#               Beta        : 0.853
#               R-squared   : 0.088
#               Traynor     : 0.713
#               Std         : 0.067
#
#               R. price    : 13.04744
#               Coef_price  : 0.23924344
#
#               R. intercept: 0.00693
#               Coef        : 0.00009529
#
#               Target_sell : 30.68
#               Actual_price: 26.90
#               Target_buy  : 24.15
#
#               Base_price  : 21.53
#               Stop_loss   : -19.95%
#
#               Dispersion  : 0.95%
#
#               Stock_return: 66.05%
# ===========> JBSS3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  40
#               Negative -  23
#               Pct Up   - 63.49
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -1.901
#               Alpha       : -0.013
#               Beta        : 0.188
#               R-squared   : 0.128
#               Traynor     : 1.424
#               Std         : 0.022
#
#               R. price    : 28.22986
#               Coef_price  : 0.10349803
#
#               R. intercept: 0.00259
#               Coef        : 0.00005984
#
#               Target_sell : 37.89
#               Actual_price: 37.39
#               Target_buy  : 34.05
#
#               Base_price  : 34.27
#               Stop_loss   : -8.34%
#
#               Dispersion  : 1.07%
#
#               Stock_return: 32.00%
# ===========> MRFG3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  42
#               Negative -  21
#               Pct Up   - 66.67
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -1.753
#               Alpha       : -0.044
#               Beta        : 0.172
#               R-squared   : 0.167
#               Traynor     : 2.516
#               Std         : 0.019
#
#               R. price    : 16.31933
#               Coef_price  : 0.11499226
#
#               R. intercept: 0.00028
#               Coef        : 0.00018780
#
#               Target_sell : 26.18
#               Actual_price: 26.15
#               Target_buy  : 23.20
#
#               Base_price  : 22.17
#               Stop_loss   : -15.21%
#
#               Dispersion  : 1.10%
#
#               Stock_return: 48.60%
# ===========> WEGE3.SA
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  29
#               Negative -  34
#               Pct Up   - 46.03
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  2
#               Negative -  1
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -2.426
#               Alpha       : 0.065
#               Beta        : 0.426
#               R-squared   : 0.250
#               Traynor     : 0.092
#               Std         : 0.021
#
#               R. price    : 33.89752
#               Coef_price  : 0.07536729
#
#               R. intercept: 0.00107
#               Coef        : 0.00001519
#
#               Target_sell : 40.46
#               Actual_price: 38.65
#               Target_buy  : 37.55
#
#               Base_price  : 37.55
#               Stop_loss   : -2.84%
#
#               Dispersion  : 1.00%
#
#               Stock_return: 9.17%
# ===========> ^GSPC
#
# ------------------------------------Daily Infos--------------------------------------
# Count:
#               Positive -  34
#               Negative -  29
#               Pct Up   - 53.97
#
# -----------------------------------Monthly Infos-------------------------------------
# Count:
#               Positive -  1
#               Negative -  2
#
#
# -----------------------------------Other Infos---------------------------------------
# Count:
#               Sharpe      : -0.083
#               Alpha       : 0.019
#               Beta        : 0.064
#               R-squared   : 0.259
#               Traynor     : -0.795
#               Std         : 0.007
#
#               R. price    : 4391.13516
#               Coef_price  : -1.12913763
#
#               R. intercept: 0.00078
#               Coef        : -0.00002298
#
#               Target_sell : 1918.71
#               Actual_price: 4391.34
#               Target_buy  : 6833.04
#
#               Base_price  : 1912.14
#               Stop_loss   : -56.46%
#
#               Dispersion  : 1.02%
#
#               Stock_return: 0.15%

# %%
import random

# Markowits
multiplicador = 30
n_days = len(stocks_all)
stocks = stocks_all['Adj Close']
log_ret = np.log(stocks / stocks.shift(1)).dropna()

# Admite que a mesma sequencia randomica
np.random.seed(42)
num_ports = multiplicador * 500 * len(stocks.columns)
all_weights = np.zeros((num_ports, len(stocks.columns)))
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharpe_arr = np.zeros(num_ports)

for x in tqdm(range(num_ports)):
    # Weights
    weights = np.array(np.random.random(len(stocks.columns)))
    weights = weights/np.sum(weights)

    # Save weights
    all_weights[x,:] = weights

    # Expected return
    ret_arr[x] = np.sum( (log_ret.mean() * weights * n_days))

    # Expected volatility
    vol_arr[x] = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * n_days, weights)))

    # Sharpe Ratio
    sharpe_arr[x] = ret_arr[x]/vol_arr[x]

# Para operar na venda utilize o agrmin()

maximo = sharpe_arr.argmax()
# maximo = sharpe_arr.argmin()

# maximo = vol_arr.argmax()
# maximo = vol_arr.argmin()

         
max_sr_ret = ret_arr[maximo]
max_sr_vol = vol_arr[maximo]
# Out:
# 100%|██████████| 90000/90000 [03:51<00:00, 389.28it/s]

# %%
plt.figure(figsize=(12,8))
plt.scatter(vol_arr, ret_arr, c=sharpe_arr, cmap='viridis')
plt.colorbar(label='Grau do Indice Sharpe ')
plt.xlabel('Risco')
plt.ylabel('Retorno')
plt.scatter(max_sr_vol, max_sr_ret,c='red', s=200) # red dot
plt.show()

# %%
# Fator expectativa
exp = (max_sr_ret - max_sr_vol)/(max_sr_ret + max_sr_vol)
expec_real = 1 +(exp/100)
# exp = expec_real**252

print("Expectativa de retorno diário:   %.3f" % exp + " %")
# Out:
# Expectativa de retorno diário:   0.433 %

# %%
finals_stocks.loc[markowitz_names]
# Out:
#          Reg_price Coef_price      Reg_int     Coef_int Rel_price_ret  \
# MRFG3.SA   16.3193   0.114992  0.000279046  0.000187801        612.31
# FHER3.SA   13.0474   0.239243   0.00693158  9.52874e-05       2510.76
# EMBR3.SA   17.8878  0.0829738   -0.0017158  0.000181751       456.523
# WEGE3.SA   33.8975  0.0753673    0.0010749  1.51851e-05       4963.23
# JBSS3.SA   28.2299   0.103498    0.0025925  5.98399e-05       1729.58
# ^GSPC      4391.14   -1.12914  0.000784554 -2.29839e-05       49127.3
#
#          Pct_up_day Pct_up_month     Sharpe Base_price Target_buy Target_sell  \
# MRFG3.SA    66.6667          NaN   -1.75337        NaN    23.1994     26.1844
# FHER3.SA    49.2063          NaN  -0.794103        NaN    24.1523     30.6767
# EMBR3.SA     47.619          NaN   -2.33486        NaN     22.207     24.1863
# WEGE3.SA    46.0317          NaN   -2.42632        NaN    37.5493     40.4551
# JBSS3.SA    63.4921          NaN   -1.90127        NaN    34.0459     37.8855
# ^GSPC       53.9683          NaN -0.0827208        NaN    6833.04     1918.71
#
#          Actual_price  Ret_real Stop_loss         Std       Beta    Traynor  \
# MRFG3.SA        26.15   48.5959  -15.2086   0.0192513   0.172306    2.51564
# FHER3.SA         26.9   66.0494  -19.9462   0.0672681   0.853162   0.712636
# EMBR3.SA        24.75   25.6345  -10.8647   0.0349886   0.681922   0.298927
# WEGE3.SA        38.65   9.16643   -2.8431   0.0210193   0.425929  0.0919502
# JBSS3.SA        37.39        32  -8.34235   0.0217156   0.187895    1.42367
# ^GSPC         4391.34  0.153034  -56.4566  0.00725161  0.0641514  -0.794522
#
#               Alpha  R-squared Dispersion
# MRFG3.SA -0.0439227   0.167344    1.10436
# FHER3.SA  0.0412342  0.0878397   0.948552
# EMBR3.SA  0.0804064   0.351248     1.0669
# WEGE3.SA  0.0650489   0.250193   0.998166
# JBSS3.SA -0.0133885   0.128468    1.07277
# ^GSPC     0.0193619    0.25938    1.01678

# %%
import warnings
warnings.filterwarnings("ignore")

# Simulacao de compra
money = 10000
last_price = stocks[-1:].iloc[0]

# Pesos na carteira
df = pd.DataFrame(index=stocks.columns, columns = ['Pesos','Valor_investido'])
df['Pesos'] = all_weights[maximo]
                    
                    # ou rb
for i in range(len(stocks.columns)):
    prop_value = money * all_weights[maximo][i]
    stocks_qtd = prop_value / finals_stocks['Actual_price'].loc[stocks.columns[i]]
    df['Valor_investido'][i] = prop_value
    
    
    
    print("##=================="+stocks.iloc[i].index[i]+"==================##")
    print()
    print("Proporcao no portifolio          :    %.2f" %(all_weights[maximo][i]*100) +"%")
    print()
    print("Numero de papeis a comprar       :        %.0f" % stocks_qtd)
    print("Valor proporcional               : R$ %.2f" % prop_value)
    print()
    print("Preço atual                      : R$ %.2f" % finals_stocks['Actual_price'].loc[stocks.columns[i]])
    print()
# Out:
# ##==================EMBR3.SA==================##
#
# Proporcao no portifolio          :    5.12%
#
# Numero de papeis a comprar       :        21
# Valor proporcional               : R$ 512.01
#
# Preço atual                      : R$ 24.75
#
# ##==================FHER3.SA==================##
#
# Proporcao no portifolio          :    1.37%
#
# Numero de papeis a comprar       :        5
# Valor proporcional               : R$ 137.45
#
# Preço atual                      : R$ 26.90
#
# ##==================JBSS3.SA==================##
#
# Proporcao no portifolio          :    20.18%
#
# Numero de papeis a comprar       :        54
# Valor proporcional               : R$ 2018.10
#
# Preço atual                      : R$ 37.39
#
# ##==================MRFG3.SA==================##
#
# Proporcao no portifolio          :    59.71%
#
# Numero de papeis a comprar       :        228
# Valor proporcional               : R$ 5971.03
#
# Preço atual                      : R$ 26.15
#
# ##==================WEGE3.SA==================##
#
# Proporcao no portifolio          :    4.06%
#
# Numero de papeis a comprar       :        11
# Valor proporcional               : R$ 406.34
#
# Preço atual                      : R$ 38.65
#
# ##==================^GSPC==================##
#
# Proporcao no portifolio          :    9.55%
#
# Numero de papeis a comprar       :        0
# Valor proporcional               : R$ 955.07
#
# Preço atual                      : R$ 4391.34

# %%
df
# Out:
#              Pesos Valor_investido
# JBSS3.SA  0.210772         2107.72
# TOTS3.SA  0.000181         1.80743
# WIZS3.SA  0.094440         944.401
# ^GSPC     0.694607         6946.07

# %% [markdown]
# <h2>Backtest</h2>

# %%
E_Year_bt = (datetime(E_Year, E_Month, E_Day).date() + timedelta(days=7)).timetuple()[0]
E_Month_bt = (datetime(E_Year, E_Month, E_Day).date() + timedelta(days=7)).timetuple()[1]
E_Day_bt = (datetime(E_Year, E_Month, E_Day).date() + timedelta(days=7)).timetuple()[2]

# %%
    ## Analise dos ativos com maior volume  
best_names = list(df.index[:])
ibov = yahoo('^BVSP',E_Day, E_Month, E_Year, E_Day_bt, E_Month_bt, E_Year_bt)
stocks_all=yahoo(best_names, E_Day, E_Month, E_Year, E_Day_bt, E_Month_bt, E_Year_bt)    
stocks_close = stocks_all['Adj Close']
stocks_all.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  4 of 4 completed
#             Adj Close                                       Close             \
#              JBSS3.SA   TOTS3.SA WIZS3.SA        ^GSPC   JBSS3.SA   TOTS3.SA
# Date
# 2021-09-22  33.090000  39.080002    13.20  4395.640137  33.090000  39.080002
# 2021-09-23  33.869999  39.130001    13.42  4448.979980  33.869999  39.130001
# 2021-09-24  35.130001  38.000000    13.81  4455.479980  35.130001  38.000000
# 2021-09-27  35.380001  36.869999    14.27  4443.109863  35.380001  36.869999
# 2021-09-28  35.189999  35.599998    12.02  4352.629883  35.189999  35.599998
#
#                                        High             ...      Low  \
#            WIZS3.SA        ^GSPC   JBSS3.SA   TOTS3.SA  ... WIZS3.SA
# Date                                                    ...
# 2021-09-22    13.20  4395.640137  33.619999  39.660000  ...    13.13
# 2021-09-23    13.42  4448.979980  34.070000  39.230000  ...    13.25
# 2021-09-24    13.81  4455.479980  35.299999  39.029999  ...    13.02
# 2021-09-27    14.27  4443.109863  35.900002  37.799999  ...    13.67
# 2021-09-28    12.02  4352.629883  35.669998  36.320000  ...    11.88
#
#                               Open                                     Volume  \
#                   ^GSPC   JBSS3.SA   TOTS3.SA WIZS3.SA        ^GSPC  JBSS3.SA
# Date
# 2021-09-22  4367.430176  32.900002  37.500000    13.47  4367.430176  14031300
# 2021-09-23  4406.750000  33.270000  39.209999    13.32  4406.750000   9573600
# 2021-09-24  4430.270020  33.720001  38.860001    13.35  4438.040039  16255800
# 2021-09-27  4436.189941  35.009998  37.799999    13.86  4442.120117  10040000
# 2021-09-28  4346.330078  35.349998  36.200001    14.12  4419.540039   8512800
#
#
#            TOTS3.SA  WIZS3.SA       ^GSPC
# Date
# 2021-09-22  6548300   3224600  3273670000
# 2021-09-23  4835200   2448900  2833290000
# 2021-09-24  6379100   2230400  2772090000
# 2021-09-27  5048500   4386300  3032870000
# 2021-09-28  5090200  13439400  3495970000
#
# [5 rows x 24 columns]

# %%
stocks_close.describe()

# %%
# Fator expectativa por normalização de risco e retorno

exp = (max_sr_ret - max_sr_vol)/(max_sr_ret + max_sr_vol)
print("Expectativa de retorno médio diário :   %.3f" % exp + " %")

# Retorno médio dos ativos somados

retorno = stocks_close.pct_change().dropna().mean().mean() * 100
print("Retorno real médio diário           :   %.3f" % retorno + " %")

# Cálculo do erro de previsão

erro = (retorno - exp)/exp
print()
print("Taxa de erro da previsão            :   %.3f" % erro + " %")

# %%
return_ibov = get_real_returns(ibov).transpose()
return_real = get_real_returns(stocks_close)
df['Retorno_real'] = return_real + 1
df

# %%
df['Montante_final'] = df['Valor_investido'] * df['Retorno_real']
round(df['Montante_final'].sum(), 2)

# %%
# Comparação do desempenho 
# Previsto
fator_multiplicador = ((len(stocks_close) * exp)/100)+1
port_predict = money * fator_multiplicador
exp_port_predict = (port_predict/money)-1
montante_real = df['Montante_final'].sum()
performance = (float((montante_real-port_predict)/port_predict))*100
port_return = ((montante_real-money)/money)*100
ret_ibov = float(return_ibov['Adj Close'].copy() * 100)


print("Previsão de lucro acumulado         : R$ %.2f" % port_predict)
print("Previsão de retorno acumulado       : %.2f" % (exp_port_predict*100)+" %")
print()
print("Montante real acumulado             : R$ %.2f" % montante_real)
print("Retorno real                        : %.2f" % port_return +" %")
print("Retorno Ibovespa                    : %.2f" % ret_ibov + " %")
print()
print("Diferença de perfomance             : %.2f" % perf_port_ibov(port_return, ret_ibov) + " pts")
print()
print("Performance algoritmo               : %.2f" % performance + " %")
